# %% [markdown]
# Questo codice racchiude i seguenti esperimenti:
#
#
# *   Train 90ped2+10synth - test ped2
# *   Train 90ped2+10synth - test MED

# %% [markdown]
# Rispetto al training precedente 90/10, qui i video sintetici sono presi in modo randomico.

# %%
import os
from pathlib import Path
import shutil
import re
import time
import natsort
import random

import cv2
from PIL import Image

import numpy as np
from scipy.io import savemat, loadmat
import scipy.io as sio
import pandas as pd

import torch

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from matplotlib.patches import Patch

from sklearn.metrics import roc_auc_score, roc_curve, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

import seaborn as sns

# %% [markdown]
# #1-🛠️Clonazione github e connessione a drive per reperire i frames

# %%
# %cd /content
# !rm -rf astnet #Pulizia
# !git clone https://github.com/marco-caruso/astnet.git
# %cd astnet
# Out:
# /content
# Cloning into 'astnet'...
# remote: Enumerating objects: 939, done.
# remote: Counting objects: 100% (141/141), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 939 (delta 120), reused 63 (delta 63), pack-reused 798 (from 2)
# Receiving objects: 100% (939/939), 45.18 MiB | 16.83 MiB/s, done.
# Resolving deltas: 100% (553/553), done.
# /content/astnet

# %%
# Installazione requirements dalla root come richiesto dal README astnet
# !pip install -r requirements.txt
# Out:
# Collecting natsort==7.0.1 (from -r requirements.txt (line 1))
#   Downloading natsort-7.0.1-py3-none-any.whl.metadata (21 kB)
# ERROR: Ignored the following yanked versions: 2.4.0
# ERROR: Ignored the following versions that require a different python version: 1.21.2 Requires-Python >=3.7,<3.11; 1.21.3 Requires-Python >=3.7,<3.11; 1.21.4 Requires-Python >=3.7,<3.11; 1.21.5 Requires-Python >=3.7,<3.11; 1.21.6 Requires-Python >=3.7,<3.11
# ERROR: Could not find a version that satisfies the requirement numpy==1.21.5 (from versions: 1.3.0, 1.4.1, 1.5.0, 1.5.1, 1.6.0, 1.6.1, 1.6.2, 1.7.0, 1.7.1, 1.7.2, 1.8.0, 1.8.1, 1.8.2, 1.9.0, 1.9.1, 1.9.2, 1.9.3, 1.10.0.post2, 1.10.1, 1.10.2, 1.10.4, 1.11.0, 1.11.1, 1.11.2, 1.11.3, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 1.13.3, 1.14.0, 1.14.1, 1.14.2, 1.14.3, 1.14.4, 1.14.5, 1.14.6, 1.15.0, 1.15.1, 1.15.2, 1.15.3, 1.15.4, 1.16.0, 1.16.1, 1.16.2, 1.16.3, 1.16.4, 1.16.5, 1.16.6, 1.17.0, 1.17.1, 1.17.2, 1.17.3, 1.17.4, 1.17.5, 1.18.0, 1.18.1, 1.18.2, 1.18.3, 1.18.4, 1.18.5, 1.19.0, 1.19.1, 1.19.2, 1.19.3, 1.19.4, 1.19.5, 1.20.0, 1.20.1, 1.20.2, 1.20.3, 1.21.0, 1.21.1, 1.22.0, 1.22.1, 1.22.2, 1.22.3, 1.22.4, 1.23.0, 1.23.1, 1.23.2, 1.23.3, 1.23.4, 1.23.5, 1.24.0, 1.24.1, 1.24.2, 1.24.3, 1.24.4, 1.25.0, 1.25.1, 1.25.2, 1.26.0, 1.26.1, 1.26.2, 1.26.3, 1.26.4, 2.0.0, 2.0.1, 2.0.2, 2.1.0, 2.1.1, 2.1.2, 2.1.3, 2.2.0, 2.2.1, 2.2.2, 2.2.3, 2.2.4, 2.2.5, 2.2.6, 2.3.0, 2.3.1, 2.3.2, 2.3.3, 2.3.4, 2.3.5, 2.4.0rc1, 2.4.1, 2.4.2, 2.4.3)
# ERROR: No matching distribution found for numpy==1.21.5

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Nota**
#
# Per gli esperimenti 90/10 con selezione manuale e casuale è stato utilizzato lo
# stesso file di configurazione .yaml "ped2_synth_3_wresnet.yaml", a differenza degli altri esperimenti.
# Questo perché, in questa configurazione, la differenza tra i due casi riguarda
# solamente un singolo video del dataset sintetico.
#
# Nell'esperimento con selezione manuale è stato utilizzato il video sintetico
# "n_0128". Successivamente lo stesso file di configurazione è stato riutilizzato
# rimuovendo tale video per eseguire l'esperimento con selezione casuale, in cui
# è stato selezionato il video "n_0029".

# %%
SOURCE_DIR = '/content/drive/MyDrive/datasets/Synth/frames/normal'
DEST_DIR = '/content/drive/MyDrive/datasets/ped2_synth_3/training/frames'
NUM_VIDEOS = 1
RANDOM_SEED = 42


os.makedirs(DEST_DIR, exist_ok=True)


all_videos = [d for d in os.listdir(SOURCE_DIR)
              if os.path.isdir(os.path.join(SOURCE_DIR, d))]

if not all_videos:
    raise ValueError(f"No videos found in {SOURCE_DIR}")

if len(all_videos) < NUM_VIDEOS:
    print(f"Only {len(all_videos)} videos available (requested {NUM_VIDEOS})")
    NUM_VIDEOS = len(all_videos)

print(f"📁 Found {len(all_videos)} total videos")

# Select random videos
random.seed(RANDOM_SEED)
selected_videos = random.sample(all_videos, NUM_VIDEOS)

print(f"\n🎲 Random seed: {RANDOM_SEED}")
print(f"✅ Selected {NUM_VIDEOS} videos:")
for i, video in enumerate(sorted(selected_videos), 1):
    print(f"  {i:2d}. {video}")

# Copy videos
print(f"\n📋 Copying to {DEST_DIR}...")
copied = 0
for i, video in enumerate(selected_videos, 1):
    src_path = os.path.join(SOURCE_DIR, video)
    dst_path = os.path.join(DEST_DIR, video)

    if os.path.exists(dst_path):
        print(f"  [{i}/{NUM_VIDEOS}] {video} - already exists, skipping")
        continue

    print(f"  [{i}/{NUM_VIDEOS}] {video}...", end='', flush=True)
    shutil.copytree(src_path, dst_path)
    copied += 1
    print(" ✓")

# Verify
final_count = len(os.listdir(DEST_DIR))
print(f"\n🎉 Done!")
print(f"✅ Copied {copied} new videos")
print(f"✅ Total videos in destination: {final_count}")
print(f"📂 Location: {DEST_DIR}")
# Out:
# 📁 Found 142 total videos
#
# 🎲 Random seed: 42
# ✅ Selected 1 videos:
#    1. n_0029
#
# 📋 Copying to /content/drive/MyDrive/datasets/ped2_synth_3/training/frames...
#   [1/1] n_0029... ✓
#
# 🎉 Done!
# ✅ Copied 1 new videos
# ✅ Total videos in destination: 17
# 📂 Location: /content/drive/MyDrive/datasets/ped2_synth_3/training/frames

# %% [markdown]
# #2-🔗Creazione dei symlink/Copia dei file da drive

# %% [markdown]
# ##2.1-Ped2

# %%
#!mkdir -p "/content/astnet/data/ped2/training"
# !mkdir -p "/content/astnet/data/ped2/testing"

# %%
print("Inizio copia dei frame:")
# !cp -r "/content/drive/MyDrive/datasets/ped2/testing/frames" "/content/astnet/data/ped2/testing/frames"

print("Copia del file ground truth...")
# !cp "/content/drive/MyDrive/datasets/ped2/ped2.mat" "/content/astnet/data/ped2/ped2.mat"

print("Finito")
# Out:
# Inizio copia dei frame:
# Copia del file ground truth...
# Finito

# %%
# !ls /content/astnet/data/ped2
#!ls /content/astnet/data/ped2/training/frames
# !ls /content/astnet/data/ped2/testing/frames
# Out:
# ped2.mat  testing
# 01  02	03  04	05  06	07  08	09  10	11  12

# %%
paths_to_fix = [
    '/content/astnet/data/ped2/testing/frames/'
]

def rename_local_frames(base_path):
    if not os.path.exists(base_path):
        print(f"Percorso non trovato: {base_path}")
        return

    subdirs = natsort.natsorted(os.listdir(base_path))
    for subdir in subdirs:
        subdir_path = os.path.join(base_path, subdir)
        if not os.path.isdir(subdir_path): continue

        files = natsort.natsorted([f for f in os.listdir(subdir_path) if f.lower().endswith(('.jpg', '.png', '.jpeg'))])
        if not files: continue

        # Controlla se il primo è 000
        if "000" in files[0]:
            print(f"Rinomino: {subdir}")
            for file_name in reversed(files):
                old_path = os.path.join(subdir_path, file_name)
                name_part, ext_part = os.path.splitext(file_name)
                try:
                    new_num = int(name_part) + 1
                    new_name = f"{new_num:03d}{ext_part.lower()}"
                    os.rename(old_path, os.path.join(subdir_path, new_name))
                except ValueError: continue
        else:
            print(f"Salta: {subdir} (già corretto)")

for p in paths_to_fix:
    rename_local_frames(p)
print("Rinomina completata in locale!")
# Out:
# Rinomino: 01
# Rinomino: 02
# Rinomino: 03
# Rinomino: 04
# Rinomino: 05
# Rinomino: 06
# Rinomino: 07
# Rinomino: 08
# Rinomino: 09
# Rinomino: 10
# Rinomino: 11
# Rinomino: 12
# Rinomina completata in locale!

# %% [markdown]
# ##2.2-Synth+ped2

# %% [markdown]
# Copiamo i frame di training di ped2+sintetici. In totale risultano 16 video di ped2 e 1 video del dataset sintetico, per avere un bilanciamento 90/10

# %%
#!mkdir -p "/content/astnet/data/synth/training"
# !mkdir -p "/content/astnet/data/ped2_synth_3/training"

# %%
print("Inizio copia dei frame di training:")
# !cp -r "/content/drive/MyDrive/datasets/ped2_synth_3/training/frames" \
      "/content/astnet/data/ped2_synth_3/training/frames/"
print("Fine copia dei frame di training.")


print("Finito")
# Out:
# Inizio copia dei frame di training:
# Fine copia dei frame di training.
# Finito

# %%
# !ls /content/astnet/data/ped2_synth_3
# !ls /content/astnet/data/ped2_synth_3/training/frames
# Out:
# training
# 01  02	03  04	05  06	07  08	09  10	11  12	13  14	15  16	17

# %% [markdown]
# Rinominiamo i frames di ped2 per farli partire da 001 invece che da 000

# %%
paths_to_fix = [
    '/content/astnet/data/ped2_synth_3/training/frames/'
]

def rename_local_frames(base_path):
    if not os.path.exists(base_path):
        print(f"Percorso non trovato: {base_path}")
        return

    subdirs = natsort.natsorted(os.listdir(base_path))
    for subdir in subdirs:
        subdir_path = os.path.join(base_path, subdir)
        if not os.path.isdir(subdir_path): continue

        files = natsort.natsorted([f for f in os.listdir(subdir_path) if f.lower().endswith(('.jpg', '.png', '.jpeg'))])
        if not files: continue

        # Controlla se il primo è 000
        if "000" in files[0]:
            print(f"Rinomino: {subdir}")
            for file_name in reversed(files):
                old_path = os.path.join(subdir_path, file_name)
                name_part, ext_part = os.path.splitext(file_name)
                try:
                    new_num = int(name_part) + 1
                    new_name = f"{new_num:03d}{ext_part.lower()}"
                    os.rename(old_path, os.path.join(subdir_path, new_name))
                except ValueError: continue
        else:
            print(f"Salta: {subdir} (già corretto)")

for p in paths_to_fix:
    rename_local_frames(p)
print("Rinomina completata in locale!")
# Out:
# Rinomino: 01
# Rinomino: 02
# Rinomino: 03
# Rinomino: 04
# Rinomino: 05
# Rinomino: 06
# Rinomino: 07
# Rinomino: 08
# Rinomino: 09
# Rinomino: 10
# Rinomino: 11
# Rinomino: 12
# Rinomino: 13
# Rinomino: 14
# Rinomino: 15
# Rinomino: 16
# Salta: 17 (già corretto)
# Rinomina completata in locale!

# %% [markdown]
# ##2.3-MED

# %%
# !mkdir -p "/content/astnet/data/med/testing"

# %%
print("Inizio copia dei frame:")
# !cp -r "/content/drive/MyDrive/datasets/med/testing/frames" "/content/astnet/data/med/testing/frames"

print("Copia del file ground truth...")
# !cp "/content/drive/MyDrive/datasets/med/med.mat" "/content/astnet/data/med/med.mat"

print("Finito")
# Out:
# Inizio copia dei frame:
# Copia del file ground truth...
# Finito

# %% [markdown]
# #3-⚙️Training

# %% [markdown]
# Il training verrà fatto con il dataset ibrido: 90% ped2 e 10% synth. Risultano 16 video del dataset ped2 (2550 frames) e 1 video del dataset sintetico (243 frames) per un totale di 2793 frames.

# %% [markdown]
# ##3.1-Ped2+synth

# %%
# %cd /content/astnet/ASTNet
# !perl -pi -e 's/\bnp\.float\b/float/g; s/\bnp\.int\b/int/g; s/\bnp\.bool\b/bool/g; s/\bnp\.object\b/object/g' utils/anomaly_util.py
# Out:
# /content/astnet/ASTNet

# %%
# !pip install yacs
# Out:
# Collecting yacs
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from yacs) (6.0.3)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Installing collected packages: yacs
# Successfully installed yacs-0.1.8

# %%
# Crea la cartella
# !mkdir -p /content/astnet/ASTNet/datasets/seg_weights/

# Copia il file da Drive
# !cp /content/drive/MyDrive/datasets/weights/wider_resnet38.pth /content/astnet/ASTNet/datasets/seg_weights/

# %%
#Modificare nel file .yaml: '/content/astnet/ASTNet/datasets/seg_weights/wider_resnet38.pth'

# %% [markdown]
# Copiamo l'ultimo checkpoint da cui ripartire, se serve

# %%
# !mkdir -p /content/astnet/ASTNet/output/ped2_synth_3/ped2_synth_3_wresnet/
# !cp /content/drive/MyDrive/datasets/Training_Backup/training_ped2_synth_3_random/epoch_40.pth /content/astnet/ASTNet/output/ped2_synth_3/ped2_synth_3_wresnet/epoch_40.pth

# %%
# !python /content/astnet/ASTNet/train.py --cfg /content/astnet/ASTNet/config/ped2_synth_3_wresnet.yaml
# Out:
# => creating output
# => creating output/ped2_synth_3/ped2_synth_3_wresnet
# => creating log/ped2_synth_3/wrn38/ped2_synth_3_wresnet_2026-03-09-16-05
# Namespace(cfg='/content/astnet/ASTNet/config/ped2_synth_3_wresnet.yaml', opts=[])
# CfgNode({'OUTPUT_DIR': 'output', 'LOG_DIR': 'log', 'GPUS': (0,), 'WORKERS': 2, 'PRINT_FREQ': 20, 'SAVE_CHECKPOINT_FREQ': 1, 'AUTO_RESUME': False, 'PIN_MEMORY': True, 'CUDNN': CfgNode({'BENCHMARK': True, 'DETERMINISTIC': False, 'ENABLED': True}), 'DATASET': CfgNode({'ROOT': '/content/astnet/data/', 'DATASET': 'ped2_synth_3', 'TRAINSET': 'training/frames', 'TESTSET': 'testing/frames', 'NUM_INCHANNELS': 3, 'NUM_FRAMES': 5, 'FRAME_STEPS': 2, 'LOWER_BOUND': 100}), 'TRAIN': CfgNode({'BATCH_SIZE_PER_GPU': 2, 'SHUFFLE': True, 'BEGIN_EPOCH': 0, 'END_EPOCH': 40, 'RESUME': False, 'CHECKPOINT': '', 'OPTIMIZER': 'adam', 'MOMENTUM': 0.0, 'WD': 0.0, 'NESTEROV': False, 'LR_TYPE': 'multistep', 'LR': 0.0002, 'LR_STEP': [50, 65], 'LR_FACTOR': 0.5}), 'TEST': CfgNode({'BATCH_SIZE_PER_GPU': 1}), 'MODEL': CfgNode({'NAME': 'wrn38', 'INIT_WEIGHTS': True, 'PRETRAINED': '/content/astnet/ASTNet/datasets/seg_weights/wider_resnet38.pth', 'IMAGE_SIZE': [224, 288], 'MEMORY_SIZE': 5, 'ENCODED_FRAMES': 4, 'DECODED_FRAMES': 0, 'EXTRA': CfgNode({'FINAL_CONV_KERNEL': 3})})})
# => wrn38_1024: (CATTN + TSM) - Ped2
# Global Average Pooling Initialized
# => Using fold div: 16
# Model: wrn38
# Number videos: 1363
# Epoch: [1][20/681]	Lr 0.000200	[inte 0.07149 + grad 0.2951 + msssim 0.0869 + L2 0.2674]	PSNR 17.48
# Epoch: [1][40/681]	Lr 0.000200	[inte 0.03358 + grad 0.1748 + msssim 0.0436 + L2 0.1833]	PSNR 20.76
# Epoch: [1][60/681]	Lr 0.000200	[inte 0.00737 + grad 0.0823 + msssim 0.0205 + L2 0.0858]	PSNR 27.35
# Epoch: [1][80/681]	Lr 0.000200	[inte 0.00466 + grad 0.0633 + msssim 0.0131 + L2 0.0682]	PSNR 29.34
# Epoch: [1][100/681]	Lr 0.000200	[inte 0.00429 + grad 0.0560 + msssim 0.0307 + L2 0.0655]	PSNR 29.69
# Epoch: [1][120/681]	Lr 0.000200	[inte 0.00392 + grad 0.0567 + msssim 0.0096 + L2 0.0626]	PSNR 30.09
# Epoch: [1][140/681]	Lr 0.000200	[inte 0.00272 + grad 0.0462 + msssim 0.0095 + L2 0.0522]	PSNR 31.67
# Epoch: [1][160/681]	Lr 0.000200	[inte 0.00282 + grad 0.0515 + msssim 0.0064 + L2 0.0531]	PSNR 31.52
# Epoch: [1][180/681]	Lr 0.000200	[inte 0.00499 + grad 0.0566 + msssim 0.0097 + L2 0.0706]	PSNR 29.04
# Epoch: [1][200/681]	Lr 0.000200	[inte 0.00334 + grad 0.0460 + msssim 0.0088 + L2 0.0578]	PSNR 30.78
# Epoch: [1][220/681]	Lr 0.000200	[inte 0.01584 + grad 0.1115 + msssim 0.0145 + L2 0.1259]	PSNR 24.02
# Epoch: [1][240/681]	Lr 0.000200	[inte 0.00239 + grad 0.0429 + msssim 0.0065 + L2 0.0489]	PSNR 32.24
# Epoch: [1][260/681]	Lr 0.000200	[inte 0.00254 + grad 0.0392 + msssim 0.0114 + L2 0.0504]	PSNR 31.97
# Epoch: [1][280/681]	Lr 0.000200	[inte 0.00259 + grad 0.0402 + msssim 0.0053 + L2 0.0509]	PSNR 31.89
# Epoch: [1][300/681]	Lr 0.000200	[inte 0.00414 + grad 0.0485 + msssim 0.0115 + L2 0.0643]	PSNR 29.85
# Epoch: [1][320/681]	Lr 0.000200	[inte 0.00244 + grad 0.0394 + msssim 0.0092 + L2 0.0494]	PSNR 32.14
# Epoch: [1][340/681]	Lr 0.000200	[inte 0.00167 + grad 0.0361 + msssim 0.0033 + L2 0.0409]	PSNR 33.79
# Epoch: [1][360/681]	Lr 0.000200	[inte 0.01149 + grad 0.0998 + msssim 0.0113 + L2 0.1072]	PSNR 25.42
# Epoch: [1][380/681]	Lr 0.000200	[inte 0.01178 + grad 0.0983 + msssim 0.0095 + L2 0.1085]	PSNR 25.31
# Epoch: [1][400/681]	Lr 0.000200	[inte 0.00156 + grad 0.0344 + msssim 0.0064 + L2 0.0395]	PSNR 34.09
# Epoch: [1][420/681]	Lr 0.000200	[inte 0.00974 + grad 0.0912 + msssim 0.0276 + L2 0.0987]	PSNR 26.14
# Epoch: [1][440/681]	Lr 0.000200	[inte 0.00251 + grad 0.0397 + msssim 0.0040 + L2 0.0501]	PSNR 32.02
# Epoch: [1][460/681]	Lr 0.000200	[inte 0.00169 + grad 0.0348 + msssim 0.0075 + L2 0.0411]	PSNR 33.74
# Epoch: [1][480/681]	Lr 0.000200	[inte 0.00176 + grad 0.0352 + msssim 0.0038 + L2 0.0420]	PSNR 33.56
# Epoch: [1][500/681]	Lr 0.000200	[inte 0.00215 + grad 0.0347 + msssim 0.0160 + L2 0.0464]	PSNR 32.70
# Epoch: [1][520/681]	Lr 0.000200	[inte 0.00202 + grad 0.0331 + msssim 0.0190 + L2 0.0449]	PSNR 32.97
# Epoch: [1][540/681]	Lr 0.000200	[inte 0.00246 + grad 0.0391 + msssim 0.0096 + L2 0.0496]	PSNR 32.11
# Epoch: [1][560/681]	Lr 0.000200	[inte 0.00153 + grad 0.0339 + msssim 0.0037 + L2 0.0391]	PSNR 34.19
# Epoch: [1][580/681]	Lr 0.000200	[inte 0.00206 + grad 0.0360 + msssim 0.0059 + L2 0.0454]	PSNR 32.87
# Epoch: [1][600/681]	Lr 0.000200	[inte 0.00209 + grad 0.0348 + msssim 0.0091 + L2 0.0457]	PSNR 32.83
# Epoch: [1][620/681]	Lr 0.000200	[inte 0.00145 + grad 0.0317 + msssim 0.0029 + L2 0.0381]	PSNR 34.41
# Epoch: [1][640/681]	Lr 0.000200	[inte 0.00180 + grad 0.0365 + msssim 0.0066 + L2 0.0424]	PSNR 33.48
# Epoch: [1][660/681]	Lr 0.000200	[inte 0.00185 + grad 0.0366 + msssim 0.0031 + L2 0.0430]	PSNR 33.35
# Epoch: [1][680/681]	Lr 0.000200	[inte 0.00143 + grad 0.0346 + msssim 0.0030 + L2 0.0378]	PSNR 34.46
# => saving model state epoch_1.pth to output/ped2_synth_3/ped2_synth_3_wresnet
#
# Epoch: [2][20/681]	Lr 0.000200	[inte 0.00191 + grad 0.0360 + msssim 0.0054 + L2 0.0437]	PSNR 33.21
# Epoch: [2][40/681]	Lr 0.000200	[inte 0.00126 + grad 0.0293 + msssim 0.0048 + L2 0.0355]	PSNR 35.02
# Epoch: [2][60/681]	Lr 0.000200	[inte 0.00125 + grad 0.0299 + msssim 0.0102 + L2 0.0353]	PSNR 35.06
# Epoch: [2][80/681]	Lr 0.000200	[inte 0.00111 + grad 0.0292 + msssim 0.0029 + L2 0.0332]	PSNR 35.59
# Epoch: [2][100/681]	Lr 0.000200	[inte 0.00149 + grad 0.0333 + msssim 0.0029 + L2 0.0386]	PSNR 34.29
# Epoch: [2][120/681]	Lr 0.000200	[inte 0.00910 + grad 0.0775 + msssim 0.0228 + L2 0.0954]	PSNR 26.43
# Epoch: [2][140/681]	Lr 0.000200	[inte 0.00241 + grad 0.0411 + msssim 0.0121 + L2 0.0491]	PSNR 32.19
# Epoch: [2][160/681]	Lr 0.000200	[inte 0.00232 + grad 0.0451 + msssim 0.0085 + L2 0.0482]	PSNR 32.36
# Epoch: [2][180/681]	Lr 0.000200	[inte 0.00203 + grad 0.0369 + msssim 0.0037 + L2 0.0450]	PSNR 32.95
# Epoch: [2][200/681]	Lr 0.000200	[inte 0.00664 + grad 0.0808 + msssim 0.0097 + L2 0.0815]	PSNR 27.80
# Epoch: [2][220/681]	Lr 0.000200	[inte 0.00151 + grad 0.0300 + msssim 0.0114 + L2 0.0388]	PSNR 34.24
# Epoch: [2][240/681]	Lr 0.000200	[inte 0.00178 + grad 0.0350 + msssim 0.0037 + L2 0.0422]	PSNR 33.52
# Epoch: [2][260/681]	Lr 0.000200	[inte 0.00599 + grad 0.0755 + msssim 0.0220 + L2 0.0774]	PSNR 28.25
# Epoch: [2][280/681]	Lr 0.000200	[inte 0.00089 + grad 0.0282 + msssim 0.0018 + L2 0.0299]	PSNR 36.52
# Epoch: [2][300/681]	Lr 0.000200	[inte 0.00169 + grad 0.0332 + msssim 0.0025 + L2 0.0411]	PSNR 33.74
# Epoch: [2][320/681]	Lr 0.000200	[inte 0.00160 + grad 0.0313 + msssim 0.0035 + L2 0.0400]	PSNR 33.97
# Epoch: [2][340/681]	Lr 0.000200	[inte 0.00147 + grad 0.0306 + msssim 0.0035 + L2 0.0384]	PSNR 34.34
# Epoch: [2][360/681]	Lr 0.000200	[inte 0.00104 + grad 0.0294 + msssim 0.0024 + L2 0.0323]	PSNR 35.84
# Epoch: [2][380/681]	Lr 0.000200	[inte 0.00138 + grad 0.0315 + msssim 0.0019 + L2 0.0371]	PSNR 34.64
# Epoch: [2][400/681]	Lr 0.000200	[inte 0.00141 + grad 0.0297 + msssim 0.0073 + L2 0.0375]	PSNR 34.53
# Epoch: [2][420/681]	Lr 0.000200	[inte 0.00245 + grad 0.0345 + msssim 0.0193 + L2 0.0495]	PSNR 32.12
# Epoch: [2][440/681]	Lr 0.000200	[inte 0.00095 + grad 0.0278 + msssim 0.0023 + L2 0.0308]	PSNR 36.26
# Epoch: [2][460/681]	Lr 0.000200	[inte 0.00160 + grad 0.0312 + msssim 0.0087 + L2 0.0400]	PSNR 33.98
# Epoch: [2][480/681]	Lr 0.000200	[inte 0.00085 + grad 0.0263 + msssim 0.0023 + L2 0.0291]	PSNR 36.73
# Epoch: [2][500/681]	Lr 0.000200	[inte 0.00089 + grad 0.0264 + msssim 0.0028 + L2 0.0298]	PSNR 36.55
# Epoch: [2][520/681]	Lr 0.000200	[inte 0.00080 + grad 0.0261 + msssim 0.0015 + L2 0.0283]	PSNR 36.99
# Epoch: [2][540/681]	Lr 0.000200	[inte 0.00749 + grad 0.0771 + msssim 0.0251 + L2 0.0865]	PSNR 27.28
# Epoch: [2][560/681]	Lr 0.000200	[inte 0.00184 + grad 0.0314 + msssim 0.0033 + L2 0.0429]	PSNR 33.36
# Epoch: [2][580/681]	Lr 0.000200	[inte 0.00119 + grad 0.0275 + msssim 0.0021 + L2 0.0345]	PSNR 35.26
# Epoch: [2][600/681]	Lr 0.000200	[inte 0.00172 + grad 0.0319 + msssim 0.0050 + L2 0.0415]	PSNR 33.66
# Epoch: [2][620/681]	Lr 0.000200	[inte 0.00070 + grad 0.0247 + msssim 0.0019 + L2 0.0264]	PSNR 37.60
# Epoch: [2][640/681]	Lr 0.000200	[inte 0.00137 + grad 0.0272 + msssim 0.0023 + L2 0.0370]	PSNR 34.67
# Epoch: [2][660/681]	Lr 0.000200	[inte 0.00074 + grad 0.0256 + msssim 0.0017 + L2 0.0271]	PSNR 37.35
# Epoch: [2][680/681]	Lr 0.000200	[inte 0.00643 + grad 0.0736 + msssim 0.0294 + L2 0.0802]	PSNR 27.94
# => saving model state epoch_2.pth to output/ped2_synth_3/ped2_synth_3_wresnet
#
# Epoch: [3][20/681]	Lr 0.000200	[inte 0.00123 + grad 0.0305 + msssim 0.0017 + L2 0.0350]	PSNR 35.14
# Epoch: [3][40/681]	Lr 0.000200	[inte 0.00115 + grad 0.0261 + msssim 0.0019 + L2 0.0339]	PSNR 35.43
# Epoch: [3][60/681]	Lr 0.000200	[inte 0.00097 + grad 0.0252 + msssim 0.0018 + L2 0.0311]	PSNR 36.17
# Epoch: [3][80/681]	Lr 0.000200	[inte 0.00384 + grad 0.0636 + msssim 0.0117 + L2 0.0619]	PSNR 30.18
# Epoch: [3][100/681]	Lr 0.000200	[inte 0.00103 + grad 0.0263 + msssim 0.0017 + L2 0.0320]	PSNR 35.91
# Epoch: [3][120/681]	Lr 0.000200	[inte 0.00145 + grad 0.0296 + msssim 0.0030 + L2 0.0381]	PSNR 34.41
# Epoch: [3][140/681]	Lr 0.000200	[inte 0.00089 + grad 0.0266 + msssim 0.0017 + L2 0.0299]	PSNR 36.51
# Epoch: [3][160/681]	Lr 0.000200	[inte 0.00157 + grad 0.0264 + msssim 0.0054 + L2 0.0396]	PSNR 34.07
# Epoch: [3][180/681]	Lr 0.000200	[inte 0.00105 + grad 0.0255 + msssim 0.0025 + L2 0.0323]	PSNR 35.82
# Epoch: [3][200/681]	Lr 0.000200	[inte 0.00054 + grad 0.0229 + msssim 0.0012 + L2 0.0232]	PSNR 38.71
# Epoch: [3][220/681]	Lr 0.000200	[inte 0.00141 + grad 0.0297 + msssim 0.0026 + L2 0.0376]	PSNR 34.52
# Epoch: [3][240/681]	Lr 0.000200	[inte 0.00138 + grad 0.0276 + msssim 0.0109 + L2 0.0371]	PSNR 34.64
# Epoch: [3][260/681]	Lr 0.000200	[inte 0.00127 + grad 0.0297 + msssim 0.0038 + L2 0.0357]	PSNR 34.97
# Epoch: [3][280/681]	Lr 0.000200	[inte 0.00093 + grad 0.0246 + msssim 0.0017 + L2 0.0305]	PSNR 36.33
# Epoch: [3][300/681]	Lr 0.000200	[inte 0.00363 + grad 0.0633 + msssim 0.0123 + L2 0.0603]	PSNR 30.42
# Epoch: [3][320/681]	Lr 0.000200	[inte 0.00108 + grad 0.0266 + msssim 0.0060 + L2 0.0328]	PSNR 35.69
# Epoch: [3][340/681]	Lr 0.000200	[inte 0.00073 + grad 0.0243 + msssim 0.0015 + L2 0.0270]	PSNR 37.38
# Epoch: [3][360/681]	Lr 0.000200	[inte 0.00125 + grad 0.0275 + msssim 0.0032 + L2 0.0353]	PSNR 35.05
# Epoch: [3][380/681]	Lr 0.000200	[inte 0.00086 + grad 0.0252 + msssim 0.0017 + L2 0.0293]	PSNR 36.68
# Epoch: [3][400/681]	Lr 0.000200	[inte 0.00088 + grad 0.0245 + msssim 0.0041 + L2 0.0296]	PSNR 36.58
# Epoch: [3][420/681]	Lr 0.000200	[inte 0.00455 + grad 0.0620 + msssim 0.0064 + L2 0.0674]	PSNR 29.44
# Epoch: [3][440/681]	Lr 0.000200	[inte 0.00124 + grad 0.0291 + msssim 0.0020 + L2 0.0352]	PSNR 35.09
# Epoch: [3][460/681]	Lr 0.000200	[inte 0.00114 + grad 0.0274 + msssim 0.0019 + L2 0.0338]	PSNR 35.45
# Epoch: [3][480/681]	Lr 0.000200	[inte 0.00086 + grad 0.0240 + msssim 0.0020 + L2 0.0294]	PSNR 36.66
# Epoch: [3][500/681]	Lr 0.000200	[inte 0.00082 + grad 0.0261 + msssim 0.0045 + L2 0.0287]	PSNR 36.87
# Epoch: [3][520/681]	Lr 0.000200	[inte 0.00080 + grad 0.0274 + msssim 0.0018 + L2 0.0283]	PSNR 36.98
# Epoch: [3][540/681]	Lr 0.000200	[inte 0.00079 + grad 0.0247 + msssim 0.0018 + L2 0.0281]	PSNR 37.06
# Epoch: [3][560/681]	Lr 0.000200	[inte 0.00092 + grad 0.0251 + msssim 0.0043 + L2 0.0303]	PSNR 36.40
# Epoch: [3][580/681]	Lr 0.000200	[inte 0.00074 + grad 0.0241 + msssim 0.0047 + L2 0.0273]	PSNR 37.30
# Epoch: [3][600/681]	Lr 0.000200	[inte 0.00079 + grad 0.0249 + msssim 0.0014 + L2 0.0282]	PSNR 37.02
# Epoch: [3][620/681]	Lr 0.000200	[inte 0.00071 + grad 0.0242 + msssim 0.0013 + L2 0.0266]	PSNR 37.53
# Epoch: [3][640/681]	Lr 0.000200	[inte 0.00068 + grad 0.0236 + msssim 0.0014 + L2 0.0260]	PSNR 37.73
# Epoch: [3][660/681]	Lr 0.000200	[inte 0.00474 + grad 0.0640 + msssim 0.0103 + L2 0.0689]	PSNR 29.26
# Epoch: [3][680/681]	Lr 0.000200	[inte 0.00083 + grad 0.0228 + msssim 0.0034 + L2 0.0288]	PSNR 36.83
# => saving model state epoch_3.pth to output/ped2_synth_3/ped2_synth_3_wresnet
#
# Epoch: [4][20/681]	Lr 0.000200	[inte 0.00138 + grad 0.0311 + msssim 0.0072 + L2 0.0371]	PSNR 34.62
# Epoch: [4][40/681]	Lr 0.000200	[inte 0.00094 + grad 0.0251 + msssim 0.0068 + L2 0.0306]	PSNR 36.31
# Epoch: [4][60/681]	Lr 0.000200	[inte 0.00152 + grad 0.0306 + msssim 0.0026 + L2 0.0389]	PSNR 34.21
# Epoch: [4][80/681]	Lr 0.000200	[inte 0.00101 + grad 0.0243 + msssim 0.0017 + L2 0.0318]	PSNR 35.97
# Epoch: [4][100/681]	Lr 0.000200	[inte 0.00077 + grad 0.0239 + msssim 0.0019 + L2 0.0278]	PSNR 37.15
# Epoch: [4][120/681]	Lr 0.000200	[inte 0.00105 + grad 0.0272 + msssim 0.0040 + L2 0.0324]	PSNR 35.81
# Epoch: [4][140/681]	Lr 0.000200	[inte 0.00103 + grad 0.0275 + msssim 0.0015 + L2 0.0321]	PSNR 35.89
# Epoch: [4][160/681]	Lr 0.000200	[inte 0.00133 + grad 0.0251 + msssim 0.0135 + L2 0.0364]	PSNR 34.79
# Epoch: [4][180/681]	Lr 0.000200	[inte 0.00128 + grad 0.0292 + msssim 0.0028 + L2 0.0358]	PSNR 34.94
# Epoch: [4][200/681]	Lr 0.000200	[inte 0.00371 + grad 0.0626 + msssim 0.0048 + L2 0.0609]	PSNR 30.33
# Epoch: [4][220/681]	Lr 0.000200	[inte 0.00090 + grad 0.0262 + msssim 0.0014 + L2 0.0300]	PSNR 36.48
# Epoch: [4][240/681]	Lr 0.000200	[inte 0.00055 + grad 0.0220 + msssim 0.0019 + L2 0.0234]	PSNR 38.63
# Epoch: [4][260/681]	Lr 0.000200	[inte 0.00063 + grad 0.0226 + msssim 0.0025 + L2 0.0250]	PSNR 38.06
# Epoch: [4][280/681]	Lr 0.000200	[inte 0.00094 + grad 0.0252 + msssim 0.0054 + L2 0.0307]	PSNR 36.29
# Epoch: [4][300/681]	Lr 0.000200	[inte 0.00106 + grad 0.0269 + msssim 0.0014 + L2 0.0325]	PSNR 35.78
# Epoch: [4][320/681]	Lr 0.000200	[inte 0.00119 + grad 0.0269 + msssim 0.0033 + L2 0.0345]	PSNR 35.27
# Epoch: [4][340/681]	Lr 0.000200	[inte 0.00079 + grad 0.0223 + msssim 0.0022 + L2 0.0280]	PSNR 37.07
# Epoch: [4][360/681]	Lr 0.000200	[inte 0.00133 + grad 0.0236 + msssim 0.0145 + L2 0.0365]	PSNR 34.78
# Epoch: [4][380/681]	Lr 0.000200	[inte 0.00136 + grad 0.0281 + msssim 0.0072 + L2 0.0369]	PSNR 34.68
# Epoch: [4][400/681]	Lr 0.000200	[inte 0.00110 + grad 0.0264 + msssim 0.0016 + L2 0.0331]	PSNR 35.62
# Epoch: [4][420/681]	Lr 0.000200	[inte 0.00440 + grad 0.0657 + msssim 0.0084 + L2 0.0663]	PSNR 29.59
# Epoch: [4][440/681]	Lr 0.000200	[inte 0.00102 + grad 0.0238 + msssim 0.0018 + L2 0.0320]	PSNR 35.92
# Epoch: [4][460/681]	Lr 0.000200	[inte 0.00086 + grad 0.0226 + msssim 0.0015 + L2 0.0294]	PSNR 36.67
# Epoch: [4][480/681]	Lr 0.000200	[inte 0.00053 + grad 0.0218 + msssim 0.0012 + L2 0.0231]	PSNR 38.75
# Epoch: [4][500/681]	Lr 0.000200	[inte 0.00099 + grad 0.0224 + msssim 0.0023 + L2 0.0315]	PSNR 36.05
# Epoch: [4][520/681]	Lr 0.000200	[inte 0.00076 + grad 0.0232 + msssim 0.0017 + L2 0.0275]	PSNR 37.22
# Epoch: [4][540/681]	Lr 0.000200	[inte 0.00096 + grad 0.0231 + msssim 0.0014 + L2 0.0309]	PSNR 36.21
# Epoch: [4][560/681]	Lr 0.000200	[inte 0.00090 + grad 0.0233 + msssim 0.0066 + L2 0.0300]	PSNR 36.47
# Epoch: [4][580/681]	Lr 0.000200	[inte 0.00072 + grad 0.0222 + msssim 0.0058 + L2 0.0268]	PSNR 37.45
# Epoch: [4][600/681]	Lr 0.000200	[inte 0.00138 + grad 0.0286 + msssim 0.0048 + L2 0.0372]	PSNR 34.61
# Epoch: [4][620/681]	Lr 0.000200	[inte 0.00101 + grad 0.0261 + msssim 0.0044 + L2 0.0318]	PSNR 35.97
# Epoch: [4][640/681]	Lr 0.000200	[inte 0.00151 + grad 0.0270 + msssim 0.0021 + L2 0.0389]	PSNR 34.23
# Epoch: [4][660/681]	Lr 0.000200	[inte 0.00094 + grad 0.0266 + msssim 0.0015 + L2 0.0307]	PSNR 36.28
# Epoch: [4][680/681]	Lr 0.000200	[inte 0.00064 + grad 0.0217 + msssim 0.0013 + L2 0.0254]	PSNR 37.93
# => saving model state epoch_4.pth to output/ped2_synth_3/ped2_synth_3_wresnet
#
# Epoch: [5][20/681]	Lr 0.000200	[inte 0.00062 + grad 0.0232 + msssim 0.0012 + L2 0.0250]	PSNR 38.07
# Epoch: [5][40/681]	Lr 0.000200	[inte 0.00105 + grad 0.0243 + msssim 0.0030 + L2 0.0325]	PSNR 35.79
# Epoch: [5][60/681]	Lr 0.000200	[inte 0.00046 + grad 0.0205 + msssim 0.0012 + L2 0.0214]	PSNR 39.40
# Epoch: [5][80/681]	Lr 0.000200	[inte 0.00095 + grad 0.0227 + msssim 0.0066 + L2 0.0308]	PSNR 36.24
# Epoch: [5][100/681]	Lr 0.000200	[inte 0.00059 + grad 0.0218 + msssim 0.0012 + L2 0.0243]	PSNR 38.32
# Epoch: [5][120/681]	Lr 0.000200	[inte 0.00073 + grad 0.0226 + msssim 0.0015 + L2 0.0269]	PSNR 37.42
# Epoch: [5][140/681]	Lr 0.000200	[inte 0.00111 + grad 0.0254 + msssim 0.0049 + L2 0.0333]	PSNR 35.57
# Epoch: [5][160/681]	Lr 0.000200	[inte 0.00129 + grad 0.0293 + msssim 0.0027 + L2 0.0359]	PSNR 34.93
# Epoch: [5][180/681]	Lr 0.000200	[inte 0.00089 + grad 0.0257 + msssim 0.0022 + L2 0.0298]	PSNR 36.52
# Epoch: [5][200/681]	Lr 0.000200	[inte 0.00048 + grad 0.0205 + msssim 0.0010 + L2 0.0219]	PSNR 39.22
# Epoch: [5][220/681]	Lr 0.000200	[inte 0.00075 + grad 0.0212 + msssim 0.0025 + L2 0.0273]	PSNR 37.29
# Epoch: [5][240/681]	Lr 0.000200	[inte 0.00062 + grad 0.0216 + msssim 0.0034 + L2 0.0249]	PSNR 38.09
# Epoch: [5][260/681]	Lr 0.000200	[inte 0.00088 + grad 0.0258 + msssim 0.0012 + L2 0.0297]	PSNR 36.57
# Epoch: [5][280/681]	Lr 0.000200	[inte 0.00119 + grad 0.0259 + msssim 0.0047 + L2 0.0344]	PSNR 35.28
# Epoch: [5][300/681]	Lr 0.000200	[inte 0.00502 + grad 0.0633 + msssim 0.0105 + L2 0.0708]	PSNR 29.02
# Epoch: [5][320/681]	Lr 0.000200	[inte 0.00080 + grad 0.0227 + msssim 0.0060 + L2 0.0283]	PSNR 36.99
# Epoch: [5][340/681]	Lr 0.000200	[inte 0.00080 + grad 0.0222 + msssim 0.0032 + L2 0.0284]	PSNR 36.97
# Epoch: [5][360/681]	Lr 0.000200	[inte 0.00112 + grad 0.0259 + msssim 0.0016 + L2 0.0335]	PSNR 35.52
# Epoch: [5][380/681]	Lr 0.000200	[inte 0.00332 + grad 0.0561 + msssim 0.0019 + L2 0.0576]	PSNR 30.81
# Epoch: [5][400/681]	Lr 0.000200	[inte 0.00086 + grad 0.0230 + msssim 0.0038 + L2 0.0293]	PSNR 36.67
# Epoch: [5][420/681]	Lr 0.000200	[inte 0.00075 + grad 0.0229 + msssim 0.0017 + L2 0.0274]	PSNR 37.27
# Epoch: [5][440/681]	Lr 0.000200	[inte 0.00420 + grad 0.0622 + msssim 0.0042 + L2 0.0648]	PSNR 29.79
# Epoch: [5][460/681]	Lr 0.000200	[inte 0.00069 + grad 0.0212 + msssim 0.0052 + L2 0.0262]	PSNR 37.65
# Epoch: [5][480/681]	Lr 0.000200	[inte 0.00531 + grad 0.0626 + msssim 0.0121 + L2 0.0728]	PSNR 28.77
# Epoch: [5][500/681]	Lr 0.000200	[inte 0.00086 + grad 0.0216 + msssim 0.0053 + L2 0.0294]	PSNR 36.66
# Epoch: [5][520/681]	Lr 0.000200	[inte 0.00057 + grad 0.0219 + msssim 0.0010 + L2 0.0238]	PSNR 38.48
# Epoch: [5][540/681]	Lr 0.000200	[inte 0.00061 + grad 0.0222 + msssim 0.0012 + L2 0.0247]	PSNR 38.17
# Epoch: [5][560/681]	Lr 0.000200	[inte 0.00128 + grad 0.0214 + msssim 0.0012 + L2 0.0357]	PSNR 34.96
# Epoch: [5][580/681]	Lr 0.000200	[inte 0.00065 + grad 0.0223 + msssim 0.0011 + L2 0.0256]	PSNR 37.86
# Epoch: [5][600/681]	Lr 0.000200	[inte 0.00085 + grad 0.0230 + msssim 0.0050 + L2 0.0292]	PSNR 36.72
# Epoch: [5][620/681]	Lr 0.000200	[inte 0.00312 + grad 0.0549 + msssim 0.0155 + L2 0.0558]	PSNR 31.08
# Epoch: [5][640/681]	Lr 0.000200	[inte 0.00094 + grad 0.0268 + msssim 0.0017 + L2 0.0307]	PSNR 36.28
# Epoch: [5][660/681]	Lr 0.000200	[inte 0.00061 + grad 0.0202 + msssim 0.0027 + L2 0.0247]	PSNR 38.17
# Epoch: [5][680/681]	Lr 0.000200	[inte 0.00065 + grad 0.0213 + msssim 0.0074 + L2 0.0254]	PSNR 37.91
# => saving model state epoch_5.pth to output/ped2_synth_3/ped2_synth_3_wresnet
#
# Epoch: [6][20/681]	Lr 0.000200	[inte 0.00439 + grad 0.0598 + msssim 0.0027 + L2 0.0663]	PSNR 29.59
# Epoch: [6][40/681]	Lr 0.000200	[inte 0.00082 + grad 0.0238 + msssim 0.0050 + L2 0.0286]	PSNR 36.90
# Epoch: [6][60/681]	Lr 0.000200	[inte 0.00523 + grad 0.0573 + msssim 0.0079 + L2 0.0723]	PSNR 28.83
# Epoch: [6][80/681]	Lr 0.000200	[inte 0.00066 + grad 0.0210 + msssim 0.0013 + L2 0.0256]	PSNR 37.84
# Epoch: [6][100/681]	Lr 0.000200	[inte 0.00062 + grad 0.0196 + msssim 0.0017 + L2 0.0248]	PSNR 38.12
# Epoch: [6][120/681]	Lr 0.000200	[inte 0.00048 + grad 0.0202 + msssim 0.0015 + L2 0.0219]	PSNR 39.21
# Epoch: [6][140/681]	Lr 0.000200	[inte 0.00318 + grad 0.0534 + msssim 0.0164 + L2 0.0564]	PSNR 31.00
# Epoch: [6][160/681]	Lr 0.000200	[inte 0.00085 + grad 0.0240 + msssim 0.0015 + L2 0.0292]	PSNR 36.72
# Epoch: [6][180/681]	Lr 0.000200	[inte 0.00051 + grad 0.0219 + msssim 0.0019 + L2 0.0225]	PSNR 38.96
# Epoch: [6][200/681]	Lr 0.000200	[inte 0.00039 + grad 0.0200 + msssim 0.0016 + L2 0.0198]	PSNR 40.09
# Epoch: [6][220/681]	Lr 0.000200	[inte 0.00033 + grad 0.0199 + msssim 0.0014 + L2 0.0182]	PSNR 40.81
# Epoch: [6][240/681]	Lr 0.000200	[inte 0.00118 + grad 0.0218 + msssim 0.0029 + L2 0.0343]	PSNR 35.32
# Epoch: [6][260/681]	Lr 0.000200	[inte 0.00078 + grad 0.0219 + msssim 0.0014 + L2 0.0280]	PSNR 37.09
# Epoch: [6][280/681]	Lr 0.000200	[inte 0.00054 + grad 0.0208 + msssim 0.0044 + L2 0.0233]	PSNR 38.69
# Epoch: [6][300/681]	Lr 0.000200	[inte 0.00115 + grad 0.0259 + msssim 0.0033 + L2 0.0340]	PSNR 35.40
# Epoch: [6][320/681]	Lr 0.000200	[inte 0.00088 + grad 0.0221 + msssim 0.0018 + L2 0.0296]	PSNR 36.59
# Epoch: [6][340/681]	Lr 0.000200	[inte 0.00066 + grad 0.0217 + msssim 0.0028 + L2 0.0258]	PSNR 37.80
# Epoch: [6][360/681]	Lr 0.000200	[inte 0.00049 + grad 0.0205 + msssim 0.0016 + L2 0.0222]	PSNR 39.08
# Epoch: [6][380/681]	Lr 0.000200	[inte 0.00327 + grad 0.0502 + msssim 0.0166 + L2 0.0572]	PSNR 30.88
# Epoch: [6][400/681]	Lr 0.000200	[inte 0.00080 + grad 0.0202 + msssim 0.0019 + L2 0.0284]	PSNR 36.96
# Epoch: [6][420/681]	Lr 0.000200	[inte 0.00074 + grad 0.0231 + msssim 0.0012 + L2 0.0272]	PSNR 37.34
# Epoch: [6][440/681]	Lr 0.000200	[inte 0.00055 + grad 0.0206 + msssim 0.0012 + L2 0.0234]	PSNR 38.65
# Epoch: [6][460/681]	Lr 0.000200	[inte 0.00098 + grad 0.0217 + msssim 0.0066 + L2 0.0313]	PSNR 36.12
# Epoch: [6][480/681]	Lr 0.000200	[inte 0.00072 + grad 0.0209 + msssim 0.0017 + L2 0.0269]	PSNR 37.42
# Epoch: [6][500/681]	Lr 0.000200	[inte 0.00048 + grad 0.0194 + msssim 0.0022 + L2 0.0220]	PSNR 39.18
# Epoch: [6][520/681]	Lr 0.000200	[inte 0.00082 + grad 0.0241 + msssim 0.0013 + L2 0.0286]	PSNR 36.90
# Epoch: [6][540/681]	Lr 0.000200	[inte 0.00203 + grad 0.0499 + msssim 0.0080 + L2 0.0450]	PSNR 32.96
# Epoch: [6][560/681]	Lr 0.000200	[inte 0.00055 + grad 0.0211 + msssim 0.0014 + L2 0.0234]	PSNR 38.63
# Epoch: [6][580/681]	Lr 0.000200	[inte 0.00078 + grad 0.0212 + msssim 0.0060 + L2 0.0279]	PSNR 37.12
# Epoch: [6][600/681]	Lr 0.000200	[inte 0.00233 + grad 0.0488 + msssim 0.0020 + L2 0.0483]	PSNR 32.34
# Epoch: [6][620/681]	Lr 0.000200	[inte 0.00040 + grad 0.0198 + msssim 0.0009 + L2 0.0201]	PSNR 39.95
# Epoch: [6][640/681]	Lr 0.000200	[inte 0.00318 + grad 0.0514 + msssim 0.0032 + L2 0.0564]	PSNR 31.00
# Epoch: [6][660/681]	Lr 0.000200	[inte 0.00054 + grad 0.0208 + msssim 0.0010 + L2 0.0233]	PSNR 38.66
# Epoch: [6][680/681]	Lr 0.000200	[inte 0.00066 + grad 0.0221 + msssim 0.0011 + L2 0.0257]	PSNR 37.83
# => saving model state epoch_6.pth to output/ped2_synth_3/ped2_synth_3_wresnet
#
# Epoch: [7][20/681]	Lr 0.000200	[inte 0.00060 + grad 0.0222 + msssim 0.0016 + L2 0.0245]	PSNR 38.22
# Epoch: [7][40/681]	Lr 0.000200	[inte 0.00076 + grad 0.0236 + msssim 0.0014 + L2 0.0276]	PSNR 37.20
# Epoch: [7][60/681]	Lr 0.000200	[inte 0.00079 + grad 0.0234 + msssim 0.0015 + L2 0.0282]	PSNR 37.03
# Epoch: [7][80/681]	Lr 0.000200	[inte 0.00110 + grad 0.0227 + msssim 0.0067 + L2 0.0332]	PSNR 35.60
# Epoch: [7][100/681]	Lr 0.000200	[inte 0.00058 + grad 0.0212 + msssim 0.0012 + L2 0.0240]	PSNR 38.40
# Epoch: [7][120/681]	Lr 0.000200	[inte 0.00088 + grad 0.0239 + msssim 0.0013 + L2 0.0297]	PSNR 36.56
# Epoch: [7][140/681]	Lr 0.000200	[inte 0.00075 + grad 0.0236 + msssim 0.0024 + L2 0.0274]	PSNR 37.25
# Epoch: [7][160/681]	Lr 0.000200	[inte 0.00064 + grad 0.0208 + msssim 0.0049 + L2 0.0253]	PSNR 37.94
# Epoch: [7][180/681]	Lr 0.000200	[inte 0.00063 + grad 0.0214 + msssim 0.0042 + L2 0.0252]	PSNR 38.00
# Epoch: [7][200/681]	Lr 0.000200	[inte 0.00075 + grad 0.0205 + msssim 0.0037 + L2 0.0275]	PSNR 37.25
# Epoch: [7][220/681]	Lr 0.000200	[inte 0.00123 + grad 0.0227 + msssim 0.0100 + L2 0.0351]	PSNR 35.11
# Epoch: [7][240/681]	Lr 0.000200	[inte 0.00094 + grad 0.0244 + msssim 0.0015 + L2 0.0306]	PSNR 36.31
# Epoch: [7][260/681]	Lr 0.000200	[inte 0.00230 + grad 0.0498 + msssim 0.0044 + L2 0.0480]	PSNR 32.40
# Epoch: [7][280/681]	Lr 0.000200	[inte 0.00088 + grad 0.0224 + msssim 0.0018 + L2 0.0297]	PSNR 36.57
# Epoch: [7][300/681]	Lr 0.000200	[inte 0.00048 + grad 0.0214 + msssim 0.0010 + L2 0.0219]	PSNR 39.22
# Epoch: [7][320/681]	Lr 0.000200	[inte 0.00075 + grad 0.0201 + msssim 0.0026 + L2 0.0273]	PSNR 37.29
# Epoch: [7][340/681]	Lr 0.000200	[inte 0.00042 + grad 0.0194 + msssim 0.0018 + L2 0.0204]	PSNR 39.82
# Epoch: [7][360/681]	Lr 0.000200	[inte 0.00036 + grad 0.0185 + msssim 0.0009 + L2 0.0189]	PSNR 40.47
# Epoch: [7][380/681]	Lr 0.000200	[inte 0.00048 + grad 0.0200 + msssim 0.0021 + L2 0.0220]	PSNR 39.18
# Epoch: [7][400/681]	Lr 0.000200	[inte 0.00041 + grad 0.0194 + msssim 0.0011 + L2 0.0203]	PSNR 39.85
# Epoch: [7][420/681]	Lr 0.000200	[inte 0.00040 + grad 0.0181 + msssim 0.0038 + L2 0.0201]	PSNR 39.96
# Epoch: [7][440/681]	Lr 0.000200	[inte 0.00080 + grad 0.0242 + msssim 0.0012 + L2 0.0282]	PSNR 37.01
# Epoch: [7][460/681]	Lr 0.000200	[inte 0.00028 + grad 0.0178 + msssim 0.0014 + L2 0.0168]	PSNR 41.52
# Epoch: [7][480/681]	Lr 0.000200	[inte 0.00097 + grad 0.0241 + msssim 0.0027 + L2 0.0312]	PSNR 36.13
# Epoch: [7][500/681]	Lr 0.000200	[inte 0.00110 + grad 0.0251 + msssim 0.0042 + L2 0.0332]	PSNR 35.59
# Epoch: [7][520/681]	Lr 0.000200	[inte 0.00042 + grad 0.0196 + msssim 0.0014 + L2 0.0206]	PSNR 39.74
# Epoch: [7][540/681]	Lr 0.000200	[inte 0.00071 + grad 0.0186 + msssim 0.0027 + L2 0.0266]	PSNR 37.51
# Epoch: [7][560/681]	Lr 0.000200	[inte 0.00067 + grad 0.0218 + msssim 0.0010 + L2 0.0260]	PSNR 37.73
# Epoch: [7][580/681]	Lr 0.000200	[inte 0.00087 + grad 0.0197 + msssim 0.0033 + L2 0.0295]	PSNR 36.63
# Epoch: [7][600/681]	Lr 0.000200	[inte 0.00043 + grad 0.0192 + msssim 0.0015 + L2 0.0207]	PSNR 39.69
# Epoch: [7][620/681]	Lr 0.000200	[inte 0.00242 + grad 0.0497 + msssim 0.0078 + L2 0.0492]	PSNR 32.18
# Epoch: [7][640/681]	Lr 0.000200	[inte 0.00351 + grad 0.0523 + msssim 0.0113 + L2 0.0593]	PSNR 30.56
# Epoch: [7][660/681]	Lr 0.000200	[inte 0.00089 + grad 0.0213 + msssim 0.0059 + L2 0.0298]	PSNR 36.53
# Epoch: [7][680/681]	Lr 0.000200	[inte 0.00354 + grad 0.0537 + msssim 0.0038 + L2 0.0595]	PSNR 30.53
# => saving model state epoch_7.pth to output/ped2_synth_3/ped2_synth_3_wresnet
#
# Epoch: [8][20/681]	Lr 0.000200	[inte 0.00082 + grad 0.0197 + msssim 0.0038 + L2 0.0286]	PSNR 36.90
# Epoch: [8][40/681]	Lr 0.000200	[inte 0.00064 + grad 0.0202 + msssim 0.0018 + L2 0.0254]	PSNR 37.93
# Epoch: [8][60/681]	Lr 0.000200	[inte 0.00126 + grad 0.0236 + msssim 0.0026 + L2 0.0355]	PSNR 35.01
# Epoch: [8][80/681]	Lr 0.000200	[inte 0.00399 + grad 0.0535 + msssim 0.0067 + L2 0.0632]	PSNR 30.01
# Epoch: [8][100/681]	Lr 0.000200	[inte 0.00113 + grad 0.0314 + msssim 0.0017 + L2 0.0336]	PSNR 35.50
# Epoch: [8][120/681]	Lr 0.000200	[inte 0.00080 + grad 0.0232 + msssim 0.0031 + L2 0.0284]	PSNR 36.97
# Epoch: [8][140/681]	Lr 0.000200	[inte 0.00040 + grad 0.0195 + msssim 0.0010 + L2 0.0199]	PSNR 40.05
# Epoch: [8][160/681]	Lr 0.000200	[inte 0.00200 + grad 0.0479 + msssim 0.0041 + L2 0.0448]	PSNR 33.00
# Epoch: [8][180/681]	Lr 0.000200	[inte 0.00069 + grad 0.0214 + msssim 0.0017 + L2 0.0263]	PSNR 37.61
# Epoch: [8][200/681]	Lr 0.000200	[inte 0.00108 + grad 0.0266 + msssim 0.0024 + L2 0.0329]	PSNR 35.68
# Epoch: [8][220/681]	Lr 0.000200	[inte 0.00031 + grad 0.0187 + msssim 0.0008 + L2 0.0177]	PSNR 41.05
# Epoch: [8][240/681]	Lr 0.000200	[inte 0.00073 + grad 0.0225 + msssim 0.0018 + L2 0.0271]	PSNR 37.37
# Epoch: [8][260/681]	Lr 0.000200	[inte 0.00058 + grad 0.0204 + msssim 0.0012 + L2 0.0240]	PSNR 38.42
# Epoch: [8][280/681]	Lr 0.000200	[inte 0.00310 + grad 0.0484 + msssim 0.0039 + L2 0.0557]	PSNR 31.11
# Epoch: [8][300/681]	Lr 0.000200	[inte 0.00073 + grad 0.0190 + msssim 0.0026 + L2 0.0270]	PSNR 37.40
# Epoch: [8][320/681]	Lr 0.000200	[inte 0.00271 + grad 0.0507 + msssim 0.0080 + L2 0.0521]	PSNR 31.69
# Epoch: [8][340/681]	Lr 0.000200	[inte 0.00090 + grad 0.0233 + msssim 0.0020 + L2 0.0300]	PSNR 36.48
# Epoch: [8][360/681]	Lr 0.000200	[inte 0.00031 + grad 0.0182 + msssim 0.0009 + L2 0.0177]	PSNR 41.04
# Epoch: [8][380/681]	Lr 0.000200	[inte 0.00051 + grad 0.0198 + msssim 0.0013 + L2 0.0226]	PSNR 38.95
# Epoch: [8][400/681]	Lr 0.000200	[inte 0.00055 + grad 0.0208 + msssim 0.0012 + L2 0.0234]	PSNR 38.63
# Epoch: [8][420/681]	Lr 0.000200	[inte 0.00047 + grad 0.0198 + msssim 0.0011 + L2 0.0217]	PSNR 39.30
# Epoch: [8][440/681]	Lr 0.000200	[inte 0.00310 + grad 0.0469 + msssim 0.0147 + L2 0.0557]	PSNR 31.10
# Epoch: [8][460/681]	Lr 0.000200	[inte 0.00045 + grad 0.0198 + msssim 0.0020 + L2 0.0213]	PSNR 39.46
# Epoch: [8][480/681]	Lr 0.000200	[inte 0.00072 + grad 0.0220 + msssim 0.0015 + L2 0.0269]	PSNR 37.42
# Epoch: [8][500/681]	Lr 0.000200	[inte 0.00044 + grad 0.0193 + msssim 0.0023 + L2 0.0209]	PSNR 39.60
# Epoch: [8][520/681]	Lr 0.000200	[inte 0.00073 + grad 0.0203 + msssim 0.0010 + L2 0.0270]	PSNR 37.39
# Epoch: [8][540/681]	Lr 0.000200	[inte 0.00056 + grad 0.0202 + msssim 0.0017 + L2 0.0236]	PSNR 38.55
# Epoch: [8][560/681]	Lr 0.000200	[inte 0.00059 + grad 0.0209 + msssim 0.0012 + L2 0.0243]	PSNR 38.32
# Epoch: [8][580/681]	Lr 0.000200	[inte 0.00074 + grad 0.0231 + msssim 0.0014 + L2 0.0271]	PSNR 37.35
# Epoch: [8][600/681]	Lr 0.000200	[inte 0.00301 + grad 0.0507 + msssim 0.0029 + L2 0.0549]	PSNR 31.23
# Epoch: [8][620/681]	Lr 0.000200	[inte 0.00063 + grad 0.0214 + msssim 0.0030 + L2 0.0252]	PSNR 38.00
# Epoch: [8][640/681]	Lr 0.000200	[inte 0.00068 + grad 0.0199 + msssim 0.0056 + L2 0.0262]	PSNR 37.67
# Epoch: [8][660/681]	Lr 0.000200	[inte 0.00066 + grad 0.0192 + msssim 0.0064 + L2 0.0256]	PSNR 37.85
# Epoch: [8][680/681]	Lr 0.000200	[inte 0.00046 + grad 0.0197 + msssim 0.0018 + L2 0.0215]	PSNR 39.37
# => saving model state epoch_8.pth to output/ped2_synth_3/ped2_synth_3_wresnet
#
# Epoch: [9][20/681]	Lr 0.000200	[inte 0.00323 + grad 0.0498 + msssim 0.0278 + L2 0.0569]	PSNR 30.92
# Epoch: [9][40/681]	Lr 0.000200	[inte 0.00048 + grad 0.0194 + msssim 0.0017 + L2 0.0219]	PSNR 39.20
# Epoch: [9][60/681]	Lr 0.000200	[inte 0.00306 + grad 0.0476 + msssim 0.0025 + L2 0.0553]	PSNR 31.16
# Epoch: [9][80/681]	Lr 0.000200	[inte 0.00057 + grad 0.0202 + msssim 0.0013 + L2 0.0238]	PSNR 38.50
# Epoch: [9][100/681]	Lr 0.000200	[inte 0.00363 + grad 0.0507 + msssim 0.0030 + L2 0.0603]	PSNR 30.42
# Epoch: [9][120/681]	Lr 0.000200	[inte 0.00047 + grad 0.0194 + msssim 0.0035 + L2 0.0216]	PSNR 39.33
# Epoch: [9][140/681]	Lr 0.000200	[inte 0.00075 + grad 0.0238 + msssim 0.0010 + L2 0.0274]	PSNR 37.25
# Epoch: [9][160/681]	Lr 0.000200	[inte 0.00052 + grad 0.0193 + msssim 0.0036 + L2 0.0228]	PSNR 38.87
# Epoch: [9][180/681]	Lr 0.000200	[inte 0.00051 + grad 0.0194 + msssim 0.0031 + L2 0.0226]	PSNR 38.92
# Epoch: [9][200/681]	Lr 0.000200	[inte 0.00298 + grad 0.0499 + msssim 0.0019 + L2 0.0546]	PSNR 31.28
# Epoch: [9][220/681]	Lr 0.000200	[inte 0.00197 + grad 0.0451 + msssim 0.0164 + L2 0.0444]	PSNR 33.08
# Epoch: [9][240/681]	Lr 0.000200	[inte 0.00152 + grad 0.0453 + msssim 0.0018 + L2 0.0390]	PSNR 34.21
# Epoch: [9][260/681]	Lr 0.000200	[inte 0.00080 + grad 0.0226 + msssim 0.0023 + L2 0.0283]	PSNR 36.98
# Epoch: [9][280/681]	Lr 0.000200	[inte 0.00035 + grad 0.0186 + msssim 0.0011 + L2 0.0186]	PSNR 40.61
# Epoch: [9][300/681]	Lr 0.000200	[inte 0.00061 + grad 0.0199 + msssim 0.0027 + L2 0.0248]	PSNR 38.14
# Epoch: [9][320/681]	Lr 0.000200	[inte 0.00241 + grad 0.0485 + msssim 0.0032 + L2 0.0491]	PSNR 32.20
# Epoch: [9][340/681]	Lr 0.000200	[inte 0.00062 + grad 0.0193 + msssim 0.0018 + L2 0.0250]	PSNR 38.08
# Epoch: [9][360/681]	Lr 0.000200	[inte 0.00067 + grad 0.0226 + msssim 0.0014 + L2 0.0259]	PSNR 37.75
# Epoch: [9][380/681]	Lr 0.000200	[inte 0.00055 + grad 0.0190 + msssim 0.0011 + L2 0.0234]	PSNR 38.65
# Epoch: [9][400/681]	Lr 0.000200	[inte 0.00106 + grad 0.0225 + msssim 0.0015 + L2 0.0326]	PSNR 35.76
# Epoch: [9][420/681]	Lr 0.000200	[inte 0.00074 + grad 0.0247 + msssim 0.0011 + L2 0.0272]	PSNR 37.34
# Epoch: [9][440/681]	Lr 0.000200	[inte 0.00047 + grad 0.0197 + msssim 0.0009 + L2 0.0217]	PSNR 39.31
# Epoch: [9][460/681]	Lr 0.000200	[inte 0.00055 + grad 0.0213 + msssim 0.0009 + L2 0.0234]	PSNR 38.65
# Epoch: [9][480/681]	Lr 0.000200	[inte 0.00063 + grad 0.0181 + msssim 0.0057 + L2 0.0251]	PSNR 38.03
# Epoch: [9][500/681]	Lr 0.000200	[inte 0.00319 + grad 0.0489 + msssim 0.0070 + L2 0.0565]	PSNR 30.98
# Epoch: [9][520/681]	Lr 0.000200	[inte 0.00264 + grad 0.0474 + msssim 0.0185 + L2 0.0514]	PSNR 31.80
# Epoch: [9][540/681]	Lr 0.000200	[inte 0.00042 + grad 0.0196 + msssim 0.0012 + L2 0.0204]	PSNR 39.84
# Epoch: [9][560/681]	Lr 0.000200	[inte 0.00052 + grad 0.0192 + msssim 0.0017 + L2 0.0227]	PSNR 38.89
# Epoch: [9][580/681]	Lr 0.000200	[inte 0.00178 + grad 0.0460 + msssim 0.0085 + L2 0.0422]	PSNR 33.51
# Epoch: [9][600/681]	Lr 0.000200	[inte 0.00070 + grad 0.0180 + msssim 0.0124 + L2 0.0265]	PSNR 37.56
# Epoch: [9][620/681]	Lr 0.000200	[inte 0.00064 + grad 0.0223 + msssim 0.0012 + L2 0.0253]	PSNR 37.95
# Epoch: [9][640/681]	Lr 0.000200	[inte 0.00287 + grad 0.0495 + msssim 0.0106 + L2 0.0535]	PSNR 31.45
# Epoch: [9][660/681]	Lr 0.000200	[inte 0.00067 + grad 0.0193 + msssim 0.0011 + L2 0.0258]	PSNR 37.78
# Epoch: [9][680/681]	Lr 0.000200	[inte 0.00058 + grad 0.0212 + msssim 0.0013 + L2 0.0240]	PSNR 38.42
# => saving model state epoch_9.pth to output/ped2_synth_3/ped2_synth_3_wresnet
#
# Epoch: [10][20/681]	Lr 0.000200	[inte 0.00055 + grad 0.0192 + msssim 0.0010 + L2 0.0236]	PSNR 38.58
# Epoch: [10][40/681]	Lr 0.000200	[inte 0.00315 + grad 0.0470 + msssim 0.0047 + L2 0.0562]	PSNR 31.03
# Epoch: [10][60/681]	Lr 0.000200	[inte 0.00060 + grad 0.0193 + msssim 0.0020 + L2 0.0245]	PSNR 38.25
# Epoch: [10][80/681]	Lr 0.000200	[inte 0.00184 + grad 0.0223 + msssim 0.0019 + L2 0.0429]	PSNR 33.37
# Epoch: [10][100/681]	Lr 0.000200	[inte 0.00054 + grad 0.0184 + msssim 0.0042 + L2 0.0232]	PSNR 38.71
# Epoch: [10][120/681]	Lr 0.000200	[inte 0.00282 + grad 0.0525 + msssim 0.0074 + L2 0.0531]	PSNR 31.52
# Epoch: [10][140/681]	Lr 0.000200	[inte 0.00061 + grad 0.0212 + msssim 0.0013 + L2 0.0247]	PSNR 38.15
# Epoch: [10][160/681]	Lr 0.000200	[inte 0.00053 + grad 0.0192 + msssim 0.0012 + L2 0.0230]	PSNR 38.79
# Epoch: [10][180/681]	Lr 0.000200	[inte 0.00061 + grad 0.0215 + msssim 0.0022 + L2 0.0248]	PSNR 38.15
# Epoch: [10][200/681]	Lr 0.000200	[inte 0.00058 + grad 0.0196 + msssim 0.0052 + L2 0.0241]	PSNR 38.38
# Epoch: [10][220/681]	Lr 0.000200	[inte 0.00048 + grad 0.0201 + msssim 0.0015 + L2 0.0220]	PSNR 39.18
# Epoch: [10][240/681]	Lr 0.000200	[inte 0.00072 + grad 0.0231 + msssim 0.0019 + L2 0.0268]	PSNR 37.46
# Epoch: [10][260/681]	Lr 0.000200	[inte 0.00047 + grad 0.0193 + msssim 0.0025 + L2 0.0216]	PSNR 39.33
# Epoch: [10][280/681]	Lr 0.000200	[inte 0.00180 + grad 0.0434 + msssim 0.0040 + L2 0.0424]	PSNR 33.47
# Epoch: [10][300/681]	Lr 0.000200	[inte 0.00043 + grad 0.0193 + msssim 0.0009 + L2 0.0208]	PSNR 39.66
# Epoch: [10][320/681]	Lr 0.000200	[inte 0.00035 + grad 0.0183 + msssim 0.0019 + L2 0.0188]	PSNR 40.52
# Epoch: [10][340/681]	Lr 0.000200	[inte 0.00074 + grad 0.0213 + msssim 0.0030 + L2 0.0271]	PSNR 37.35
# Epoch: [10][360/681]	Lr 0.000200	[inte 0.00047 + grad 0.0193 + msssim 0.0019 + L2 0.0216]	PSNR 39.33
# Epoch: [10][380/681]	Lr 0.000200	[inte 0.00086 + grad 0.0200 + msssim 0.0040 + L2 0.0294]	PSNR 36.65
# Epoch: [10][400/681]	Lr 0.000200	[inte 0.00041 + grad 0.0190 + msssim 0.0029 + L2 0.0202]	PSNR 39.91
# Epoch: [10][420/681]	Lr 0.000200	[inte 0.00189 + grad 0.0452 + msssim 0.0089 + L2 0.0434]	PSNR 33.26
# Epoch: [10][440/681]	Lr 0.000200	[inte 0.00045 + grad 0.0186 + msssim 0.0012 + L2 0.0213]	PSNR 39.44
# Epoch: [10][460/681]	Lr 0.000200	[inte 0.00065 + grad 0.0212 + msssim 0.0011 + L2 0.0255]	PSNR 37.87
# Epoch: [10][480/681]	Lr 0.000200	[inte 0.00082 + grad 0.0247 + msssim 0.0016 + L2 0.0286]	PSNR 36.89
# Epoch: [10][500/681]	Lr 0.000200	[inte 0.00057 + grad 0.0199 + msssim 0.0021 + L2 0.0239]	PSNR 38.46
# Epoch: [10][520/681]	Lr 0.000200	[inte 0.00101 + grad 0.0224 + msssim 0.0012 + L2 0.0318]	PSNR 35.97
# Epoch: [10][540/681]	Lr 0.000200	[inte 0.00072 + grad 0.0190 + msssim 0.0013 + L2 0.0268]	PSNR 37.46
# Epoch: [10][560/681]	Lr 0.000200	[inte 0.00336 + grad 0.0479 + msssim 0.0199 + L2 0.0580]	PSNR 30.75
# Epoch: [10][580/681]	Lr 0.000200	[inte 0.00073 + grad 0.0200 + msssim 0.0030 + L2 0.0270]	PSNR 37.39
# Epoch: [10][600/681]	Lr 0.000200	[inte 0.00264 + grad 0.0480 + msssim 0.0062 + L2 0.0514]	PSNR 31.80
# Epoch: [10][620/681]	Lr 0.000200	[inte 0.00052 + grad 0.0186 + msssim 0.0016 + L2 0.0228]	PSNR 38.88
# Epoch: [10][640/681]	Lr 0.000200	[inte 0.00071 + grad 0.0190 + msssim 0.0038 + L2 0.0267]	PSNR 37.49
# Epoch: [10][660/681]	Lr 0.000200	[inte 0.00048 + grad 0.0191 + msssim 0.0026 + L2 0.0220]	PSNR 39.18
# Epoch: [10][680/681]	Lr 0.000200	[inte 0.00041 + grad 0.0189 + msssim 0.0010 + L2 0.0203]	PSNR 39.85
# => saving model state epoch_10.pth to output/ped2_synth_3/ped2_synth_3_wresnet
#
# Epoch: [11][20/681]	Lr 0.000200	[inte 0.00049 + grad 0.0193 + msssim 0.0015 + L2 0.0221]	PSNR 39.11
# Epoch: [11][40/681]	Lr 0.000200	[inte 0.00046 + grad 0.0191 + msssim 0.0008 + L2 0.0214]	PSNR 39.43
# Epoch: [11][60/681]	Lr 0.000200	[inte 0.00054 + grad 0.0174 + msssim 0.0053 + L2 0.0233]	PSNR 38.69
# Epoch: [11][80/681]	Lr 0.000200	[inte 0.00037 + grad 0.0179 + msssim 0.0011 + L2 0.0192]	PSNR 40.34
# Epoch: [11][100/681]	Lr 0.000200	[inte 0.00190 + grad 0.0438 + msssim 0.0067 + L2 0.0436]	PSNR 33.24
# Epoch: [11][120/681]	Lr 0.000200	[inte 0.00035 + grad 0.0177 + msssim 0.0007 + L2 0.0186]	PSNR 40.62
# Epoch: [11][140/681]	Lr 0.000200	[inte 0.00093 + grad 0.0188 + msssim 0.0022 + L2 0.0305]	PSNR 36.34
# Epoch: [11][160/681]	Lr 0.000200	[inte 0.00053 + grad 0.0177 + msssim 0.0012 + L2 0.0229]	PSNR 38.81
# Epoch: [11][180/681]	Lr 0.000200	[inte 0.00255 + grad 0.0472 + msssim 0.0140 + L2 0.0505]	PSNR 31.96
# Epoch: [11][200/681]	Lr 0.000200	[inte 0.00072 + grad 0.0200 + msssim 0.0021 + L2 0.0269]	PSNR 37.44
# Epoch: [11][220/681]	Lr 0.000200	[inte 0.00086 + grad 0.0228 + msssim 0.0013 + L2 0.0293]	PSNR 36.67
# Epoch: [11][240/681]	Lr 0.000200	[inte 0.00049 + grad 0.0184 + msssim 0.0009 + L2 0.0220]	PSNR 39.16
# Epoch: [11][260/681]	Lr 0.000200	[inte 0.00033 + grad 0.0177 + msssim 0.0016 + L2 0.0182]	PSNR 40.81
# Epoch: [11][280/681]	Lr 0.000200	[inte 0.00169 + grad 0.0448 + msssim 0.0107 + L2 0.0411]	PSNR 33.73
# Epoch: [11][300/681]	Lr 0.000200	[inte 0.00066 + grad 0.0180 + msssim 0.0073 + L2 0.0257]	PSNR 37.83
# Epoch: [11][320/681]	Lr 0.000200	[inte 0.00063 + grad 0.0230 + msssim 0.0011 + L2 0.0252]	PSNR 38.01
# Epoch: [11][340/681]	Lr 0.000200	[inte 0.00028 + grad 0.0167 + msssim 0.0008 + L2 0.0168]	PSNR 41.51
# Epoch: [11][360/681]	Lr 0.000200	[inte 0.00046 + grad 0.0198 + msssim 0.0016 + L2 0.0214]	PSNR 39.42
# Epoch: [11][380/681]	Lr 0.000200	[inte 0.00034 + grad 0.0178 + msssim 0.0011 + L2 0.0184]	PSNR 40.73
# Epoch: [11][400/681]	Lr 0.000200	[inte 0.00449 + grad 0.0481 + msssim 0.0222 + L2 0.0670]	PSNR 29.50
# Epoch: [11][420/681]	Lr 0.000200	[inte 0.00071 + grad 0.0222 + msssim 0.0019 + L2 0.0267]	PSNR 37.48
# Epoch: [11][440/681]	Lr 0.000200	[inte 0.00041 + grad 0.0194 + msssim 0.0011 + L2 0.0202]	PSNR 39.92
# Epoch: [11][460/681]	Lr 0.000200	[inte 0.00250 + grad 0.0458 + msssim 0.0096 + L2 0.0500]	PSNR 32.03
# Epoch: [11][480/681]	Lr 0.000200	[inte 0.00054 + grad 0.0194 + msssim 0.0025 + L2 0.0232]	PSNR 38.71
# Epoch: [11][500/681]	Lr 0.000200	[inte 0.00046 + grad 0.0173 + msssim 0.0029 + L2 0.0215]	PSNR 39.36
# Epoch: [11][520/681]	Lr 0.000200	[inte 0.00084 + grad 0.0215 + msssim 0.0087 + L2 0.0289]	PSNR 36.80
# Epoch: [11][540/681]	Lr 0.000200	[inte 0.00066 + grad 0.0216 + msssim 0.0015 + L2 0.0256]	PSNR 37.86
# Epoch: [11][560/681]	Lr 0.000200	[inte 0.00042 + grad 0.0191 + msssim 0.0014 + L2 0.0205]	PSNR 39.79
# Epoch: [11][580/681]	Lr 0.000200	[inte 0.00054 + grad 0.0184 + msssim 0.0010 + L2 0.0232]	PSNR 38.71
# Epoch: [11][600/681]	Lr 0.000200	[inte 0.00249 + grad 0.0448 + msssim 0.0036 + L2 0.0499]	PSNR 32.06
# Epoch: [11][620/681]	Lr 0.000200	[inte 0.00077 + grad 0.0244 + msssim 0.0012 + L2 0.0277]	PSNR 37.17
# Epoch: [11][640/681]	Lr 0.000200	[inte 0.00043 + grad 0.0184 + msssim 0.0014 + L2 0.0207]	PSNR 39.69
# Epoch: [11][660/681]	Lr 0.000200	[inte 0.00031 + grad 0.0173 + msssim 0.0008 + L2 0.0175]	PSNR 41.15
# Epoch: [11][680/681]	Lr 0.000200	[inte 0.00068 + grad 0.0179 + msssim 0.0049 + L2 0.0260]	PSNR 37.72
# => saving model state epoch_11.pth to output/ped2_synth_3/ped2_synth_3_wresnet
#
# Epoch: [12][20/681]	Lr 0.000200	[inte 0.00040 + grad 0.0171 + msssim 0.0007 + L2 0.0199]	PSNR 40.05
# Epoch: [12][40/681]	Lr 0.000200	[inte 0.00037 + grad 0.0173 + msssim 0.0009 + L2 0.0192]	PSNR 40.33
# Epoch: [12][60/681]	Lr 0.000200	[inte 0.00051 + grad 0.0178 + msssim 0.0009 + L2 0.0226]	PSNR 38.94
# Epoch: [12][80/681]	Lr 0.000200	[inte 0.00045 + grad 0.0186 + msssim 0.0009 + L2 0.0212]	PSNR 39.48
# Epoch: [12][100/681]	Lr 0.000200	[inte 0.00075 + grad 0.0217 + msssim 0.0017 + L2 0.0273]	PSNR 37.29
# Epoch: [12][120/681]	Lr 0.000200	[inte 0.00083 + grad 0.0223 + msssim 0.0075 + L2 0.0288]	PSNR 36.85
# Epoch: [12][140/681]	Lr 0.000200	[inte 0.00268 + grad 0.0442 + msssim 0.0051 + L2 0.0518]	PSNR 31.73
# Epoch: [12][160/681]	Lr 0.000200	[inte 0.00075 + grad 0.0223 + msssim 0.0018 + L2 0.0274]	PSNR 37.28
# Epoch: [12][180/681]	Lr 0.000200	[inte 0.00038 + grad 0.0180 + msssim 0.0010 + L2 0.0195]	PSNR 40.21
# Epoch: [12][200/681]	Lr 0.000200	[inte 0.00044 + grad 0.0181 + msssim 0.0024 + L2 0.0209]	PSNR 39.63
# Epoch: [12][220/681]	Lr 0.000200	[inte 0.00055 + grad 0.0186 + msssim 0.0013 + L2 0.0234]	PSNR 38.62
# Epoch: [12][240/681]	Lr 0.000200	[inte 0.00170 + grad 0.0410 + msssim 0.0076 + L2 0.0412]	PSNR 33.72
# Epoch: [12][260/681]	Lr 0.000200	[inte 0.00065 + grad 0.0194 + msssim 0.0010 + L2 0.0255]	PSNR 37.88
# Epoch: [12][280/681]	Lr 0.000200	[inte 0.00067 + grad 0.0198 + msssim 0.0010 + L2 0.0259]	PSNR 37.76
# Epoch: [12][300/681]	Lr 0.000200	[inte 0.00108 + grad 0.0258 + msssim 0.0037 + L2 0.0328]	PSNR 35.69
# Epoch: [12][320/681]	Lr 0.000200	[inte 0.00042 + grad 0.0190 + msssim 0.0013 + L2 0.0204]	PSNR 39.84
# Epoch: [12][340/681]	Lr 0.000200	[inte 0.00055 + grad 0.0211 + msssim 0.0009 + L2 0.0234]	PSNR 38.63
# Epoch: [12][360/681]	Lr 0.000200	[inte 0.00054 + grad 0.0191 + msssim 0.0019 + L2 0.0231]	PSNR 38.74
# Epoch: [12][380/681]	Lr 0.000200	[inte 0.00036 + grad 0.0176 + msssim 0.0018 + L2 0.0190]	PSNR 40.46
# Epoch: [12][400/681]	Lr 0.000200	[inte 0.00044 + grad 0.0183 + msssim 0.0021 + L2 0.0209]	PSNR 39.60
# Epoch: [12][420/681]	Lr 0.000200	[inte 0.00044 + grad 0.0190 + msssim 0.0019 + L2 0.0209]	PSNR 39.62
# Epoch: [12][440/681]	Lr 0.000200	[inte 0.00250 + grad 0.0441 + msssim 0.0020 + L2 0.0500]	PSNR 32.04
# Epoch: [12][460/681]	Lr 0.000200	[inte 0.00055 + grad 0.0205 + msssim 0.0008 + L2 0.0234]	PSNR 38.64
# Epoch: [12][480/681]	Lr 0.000200	[inte 0.00054 + grad 0.0189 + msssim 0.0026 + L2 0.0233]	PSNR 38.67
# Epoch: [12][500/681]	Lr 0.000200	[inte 0.00245 + grad 0.0431 + msssim 0.0016 + L2 0.0495]	PSNR 32.13
# Epoch: [12][520/681]	Lr 0.000200	[inte 0.00047 + grad 0.0181 + msssim 0.0010 + L2 0.0216]	PSNR 39.31
# Epoch: [12][540/681]	Lr 0.000200	[inte 0.00181 + grad 0.0424 + msssim 0.0197 + L2 0.0425]	PSNR 33.45
# Epoch: [12][560/681]	Lr 0.000200	[inte 0.00050 + grad 0.0184 + msssim 0.0022 + L2 0.0224]	PSNR 39.02
# Epoch: [12][580/681]	Lr 0.000200	[inte 0.00042 + grad 0.0184 + msssim 0.0015 + L2 0.0204]	PSNR 39.82
# Epoch: [12][600/681]	Lr 0.000200	[inte 0.00065 + grad 0.0204 + msssim 0.0017 + L2 0.0254]	PSNR 37.91
# Epoch: [12][620/681]	Lr 0.000200	[inte 0.00037 + grad 0.0174 + msssim 0.0018 + L2 0.0191]	PSNR 40.39
# Epoch: [12][640/681]	Lr 0.000200	[inte 0.00042 + grad 0.0179 + msssim 0.0033 + L2 0.0205]	PSNR 39.79
# Epoch: [12][660/681]	Lr 0.000200	[inte 0.00052 + grad 0.0181 + msssim 0.0015 + L2 0.0227]	PSNR 38.90
# Epoch: [12][680/681]	Lr 0.000200	[inte 0.00054 + grad 0.0185 + msssim 0.0033 + L2 0.0231]	PSNR 38.74
# => saving model state epoch_12.pth to output/ped2_synth_3/ped2_synth_3_wresnet
#
# Epoch: [13][20/681]	Lr 0.000200	[inte 0.00041 + grad 0.0184 + msssim 0.0018 + L2 0.0202]	PSNR 39.93
# Epoch: [13][40/681]	Lr 0.000200	[inte 0.00042 + grad 0.0183 + msssim 0.0014 + L2 0.0205]	PSNR 39.78
# Epoch: [13][60/681]	Lr 0.000200	[inte 0.00044 + grad 0.0184 + msssim 0.0009 + L2 0.0209]	PSNR 39.61
# Epoch: [13][80/681]	Lr 0.000200	[inte 0.00037 + grad 0.0182 + msssim 0.0010 + L2 0.0193]	PSNR 40.32
# Epoch: [13][100/681]	Lr 0.000200	[inte 0.00029 + grad 0.0168 + msssim 0.0015 + L2 0.0169]	PSNR 41.44
# Epoch: [13][120/681]	Lr 0.000200	[inte 0.00098 + grad 0.0204 + msssim 0.0016 + L2 0.0313]	PSNR 36.11
# Epoch: [13][140/681]	Lr 0.000200	[inte 0.00056 + grad 0.0207 + msssim 0.0015 + L2 0.0237]	PSNR 38.54
# Epoch: [13][160/681]	Lr 0.000200	[inte 0.00029 + grad 0.0175 + msssim 0.0007 + L2 0.0169]	PSNR 41.46
# Epoch: [13][180/681]	Lr 0.000200	[inte 0.00033 + grad 0.0185 + msssim 0.0011 + L2 0.0182]	PSNR 40.83
# Epoch: [13][200/681]	Lr 0.000200	[inte 0.00231 + grad 0.0457 + msssim 0.0056 + L2 0.0480]	PSNR 32.39
# Epoch: [13][220/681]	Lr 0.000200	[inte 0.00284 + grad 0.0469 + msssim 0.0065 + L2 0.0533]	PSNR 31.48
# Epoch: [13][240/681]	Lr 0.000200	[inte 0.00071 + grad 0.0202 + msssim 0.0010 + L2 0.0267]	PSNR 37.49
# Epoch: [13][260/681]	Lr 0.000200	[inte 0.00087 + grad 0.0185 + msssim 0.0033 + L2 0.0296]	PSNR 36.60
# Epoch: [13][280/681]	Lr 0.000200	[inte 0.00052 + grad 0.0213 + msssim 0.0009 + L2 0.0228]	PSNR 38.85
# Epoch: [13][300/681]	Lr 0.000200	[inte 0.00034 + grad 0.0176 + msssim 0.0007 + L2 0.0185]	PSNR 40.66
# Epoch: [13][320/681]	Lr 0.000200	[inte 0.00177 + grad 0.0435 + msssim 0.0045 + L2 0.0421]	PSNR 33.54
# Epoch: [13][340/681]	Lr 0.000200	[inte 0.00224 + grad 0.0464 + msssim 0.0063 + L2 0.0473]	PSNR 32.52
# Epoch: [13][360/681]	Lr 0.000200	[inte 0.00040 + grad 0.0185 + msssim 0.0009 + L2 0.0200]	PSNR 39.99
# Epoch: [13][380/681]	Lr 0.000200	[inte 0.00025 + grad 0.0168 + msssim 0.0015 + L2 0.0159]	PSNR 41.99
# Epoch: [13][400/681]	Lr 0.000200	[inte 0.00030 + grad 0.0171 + msssim 0.0008 + L2 0.0174]	PSNR 41.19
# Epoch: [13][420/681]	Lr 0.000200	[inte 0.00048 + grad 0.0200 + msssim 0.0018 + L2 0.0218]	PSNR 39.23
# Epoch: [13][440/681]	Lr 0.000200	[inte 0.00077 + grad 0.0201 + msssim 0.0011 + L2 0.0277]	PSNR 37.16
# Epoch: [13][460/681]	Lr 0.000200	[inte 0.00039 + grad 0.0181 + msssim 0.0014 + L2 0.0198]	PSNR 40.07
# Epoch: [13][480/681]	Lr 0.000200	[inte 0.00043 + grad 0.0172 + msssim 0.0062 + L2 0.0208]	PSNR 39.67
# Epoch: [13][500/681]	Lr 0.000200	[inte 0.00054 + grad 0.0209 + msssim 0.0016 + L2 0.0233]	PSNR 38.69
# Epoch: [13][520/681]	Lr 0.000200	[inte 0.00061 + grad 0.0187 + msssim 0.0009 + L2 0.0247]	PSNR 38.17
# Epoch: [13][540/681]	Lr 0.000200	[inte 0.00042 + grad 0.0178 + msssim 0.0009 + L2 0.0205]	PSNR 39.78
# Epoch: [13][560/681]	Lr 0.000200	[inte 0.00045 + grad 0.0190 + msssim 0.0007 + L2 0.0212]	PSNR 39.48
# Epoch: [13][580/681]	Lr 0.000200	[inte 0.00029 + grad 0.0174 + msssim 0.0009 + L2 0.0170]	PSNR 41.40
# Epoch: [13][600/681]	Lr 0.000200	[inte 0.00154 + grad 0.0393 + msssim 0.0057 + L2 0.0393]	PSNR 34.13
# Epoch: [13][620/681]	Lr 0.000200	[inte 0.00056 + grad 0.0205 + msssim 0.0010 + L2 0.0236]	PSNR 38.56
# Epoch: [13][640/681]	Lr 0.000200	[inte 0.00202 + grad 0.0426 + msssim 0.0048 + L2 0.0450]	PSNR 32.96
# Epoch: [13][660/681]	Lr 0.000200	[inte 0.00035 + grad 0.0174 + msssim 0.0008 + L2 0.0188]	PSNR 40.55
# Epoch: [13][680/681]	Lr 0.000200	[inte 0.00030 + grad 0.0171 + msssim 0.0009 + L2 0.0174]	PSNR 41.20
# => saving model state epoch_13.pth to output/ped2_synth_3/ped2_synth_3_wresnet
#
# Epoch: [14][20/681]	Lr 0.000200	[inte 0.00076 + grad 0.0238 + msssim 0.0013 + L2 0.0275]	PSNR 37.22
# Epoch: [14][40/681]	Lr 0.000200	[inte 0.00056 + grad 0.0202 + msssim 0.0014 + L2 0.0236]	PSNR 38.58
# Epoch: [14][60/681]	Lr 0.000200	[inte 0.00055 + grad 0.0208 + msssim 0.0010 + L2 0.0234]	PSNR 38.63
# Epoch: [14][80/681]	Lr 0.000200	[inte 0.00295 + grad 0.0436 + msssim 0.0051 + L2 0.0543]	PSNR 31.32
# Epoch: [14][100/681]	Lr 0.000200	[inte 0.00069 + grad 0.0210 + msssim 0.0015 + L2 0.0263]	PSNR 37.61
# Epoch: [14][120/681]	Lr 0.000200	[inte 0.00034 + grad 0.0178 + msssim 0.0011 + L2 0.0183]	PSNR 40.77
# Epoch: [14][140/681]	Lr 0.000200	[inte 0.00046 + grad 0.0181 + msssim 0.0015 + L2 0.0216]	PSNR 39.35
# Epoch: [14][160/681]	Lr 0.000200	[inte 0.00191 + grad 0.0405 + msssim 0.0044 + L2 0.0437]	PSNR 33.22
# Epoch: [14][180/681]	Lr 0.000200	[inte 0.00071 + grad 0.0185 + msssim 0.0078 + L2 0.0267]	PSNR 37.50
# Epoch: [14][200/681]	Lr 0.000200	[inte 0.00034 + grad 0.0183 + msssim 0.0009 + L2 0.0185]	PSNR 40.69
# Epoch: [14][220/681]	Lr 0.000200	[inte 0.00063 + grad 0.0176 + msssim 0.0027 + L2 0.0251]	PSNR 38.04
# Epoch: [14][240/681]	Lr 0.000200	[inte 0.00045 + grad 0.0185 + msssim 0.0013 + L2 0.0213]	PSNR 39.44
# ...
# Epoch: [36][360/681]	Lr 0.000200	[inte 0.00024 + grad 0.0153 + msssim 0.0007 + L2 0.0155]	PSNR 42.23
# Epoch: [36][380/681]	Lr 0.000200	[inte 0.00037 + grad 0.0192 + msssim 0.0005 + L2 0.0193]	PSNR 40.32
# Epoch: [36][400/681]	Lr 0.000200	[inte 0.00042 + grad 0.0203 + msssim 0.0009 + L2 0.0204]	PSNR 39.81
# Epoch: [36][420/681]	Lr 0.000200	[inte 0.00025 + grad 0.0162 + msssim 0.0007 + L2 0.0158]	PSNR 42.04
# Epoch: [36][440/681]	Lr 0.000200	[inte 0.00024 + grad 0.0156 + msssim 0.0011 + L2 0.0156]	PSNR 42.18
# Epoch: [36][460/681]	Lr 0.000200	[inte 0.00136 + grad 0.0336 + msssim 0.0029 + L2 0.0368]	PSNR 34.70
# Epoch: [36][480/681]	Lr 0.000200	[inte 0.00027 + grad 0.0160 + msssim 0.0022 + L2 0.0165]	PSNR 41.68
# Epoch: [36][500/681]	Lr 0.000200	[inte 0.00028 + grad 0.0173 + msssim 0.0010 + L2 0.0169]	PSNR 41.48
# Epoch: [36][520/681]	Lr 0.000200	[inte 0.00038 + grad 0.0161 + msssim 0.0008 + L2 0.0195]	PSNR 40.20
# Epoch: [36][540/681]	Lr 0.000200	[inte 0.00032 + grad 0.0154 + msssim 0.0022 + L2 0.0178]	PSNR 41.00
# Epoch: [36][560/681]	Lr 0.000200	[inte 0.00034 + grad 0.0169 + msssim 0.0011 + L2 0.0185]	PSNR 40.69
# Epoch: [36][580/681]	Lr 0.000200	[inte 0.00024 + grad 0.0169 + msssim 0.0007 + L2 0.0155]	PSNR 42.20
# Epoch: [36][600/681]	Lr 0.000200	[inte 0.00039 + grad 0.0182 + msssim 0.0008 + L2 0.0198]	PSNR 40.10
# Epoch: [36][620/681]	Lr 0.000200	[inte 0.00032 + grad 0.0180 + msssim 0.0008 + L2 0.0180]	PSNR 40.93
# Epoch: [36][640/681]	Lr 0.000200	[inte 0.00025 + grad 0.0164 + msssim 0.0007 + L2 0.0159]	PSNR 42.01
# Epoch: [36][660/681]	Lr 0.000200	[inte 0.00028 + grad 0.0150 + msssim 0.0007 + L2 0.0166]	PSNR 41.63
# Epoch: [36][680/681]	Lr 0.000200	[inte 0.00027 + grad 0.0160 + msssim 0.0016 + L2 0.0165]	PSNR 41.67
# => saving model state epoch_36.pth to output/ped2_synth_3/ped2_synth_3_wresnet
#
# Epoch: [37][20/681]	Lr 0.000200	[inte 0.00036 + grad 0.0181 + msssim 0.0010 + L2 0.0191]	PSNR 40.42
# Epoch: [37][40/681]	Lr 0.000200	[inte 0.00024 + grad 0.0168 + msssim 0.0006 + L2 0.0154]	PSNR 42.28
# Epoch: [37][60/681]	Lr 0.000200	[inte 0.00154 + grad 0.0350 + msssim 0.0118 + L2 0.0392]	PSNR 34.14
# Epoch: [37][80/681]	Lr 0.000200	[inte 0.00036 + grad 0.0164 + msssim 0.0021 + L2 0.0189]	PSNR 40.50
# Epoch: [37][100/681]	Lr 0.000200	[inte 0.00033 + grad 0.0171 + msssim 0.0007 + L2 0.0181]	PSNR 40.89
# Epoch: [37][120/681]	Lr 0.000200	[inte 0.00016 + grad 0.0152 + msssim 0.0005 + L2 0.0128]	PSNR 43.91
# Epoch: [37][140/681]	Lr 0.000200	[inte 0.00032 + grad 0.0155 + msssim 0.0009 + L2 0.0179]	PSNR 40.96
# Epoch: [37][160/681]	Lr 0.000200	[inte 0.00028 + grad 0.0154 + msssim 0.0007 + L2 0.0166]	PSNR 41.60
# Epoch: [37][180/681]	Lr 0.000200	[inte 0.00028 + grad 0.0160 + msssim 0.0010 + L2 0.0166]	PSNR 41.61
# Epoch: [37][200/681]	Lr 0.000200	[inte 0.00033 + grad 0.0181 + msssim 0.0006 + L2 0.0181]	PSNR 40.84
# Epoch: [37][220/681]	Lr 0.000200	[inte 0.00099 + grad 0.0347 + msssim 0.0031 + L2 0.0315]	PSNR 36.04
# Epoch: [37][240/681]	Lr 0.000200	[inte 0.00037 + grad 0.0164 + msssim 0.0039 + L2 0.0192]	PSNR 40.35
# Epoch: [37][260/681]	Lr 0.000200	[inte 0.00027 + grad 0.0155 + msssim 0.0014 + L2 0.0163]	PSNR 41.75
# Epoch: [37][280/681]	Lr 0.000200	[inte 0.00028 + grad 0.0167 + msssim 0.0021 + L2 0.0167]	PSNR 41.59
# Epoch: [37][300/681]	Lr 0.000200	[inte 0.00105 + grad 0.0326 + msssim 0.0083 + L2 0.0325]	PSNR 35.80
# Epoch: [37][320/681]	Lr 0.000200	[inte 0.00032 + grad 0.0181 + msssim 0.0006 + L2 0.0178]	PSNR 41.03
# Epoch: [37][340/681]	Lr 0.000200	[inte 0.00021 + grad 0.0157 + msssim 0.0006 + L2 0.0146]	PSNR 42.76
# Epoch: [37][360/681]	Lr 0.000200	[inte 0.00031 + grad 0.0163 + msssim 0.0040 + L2 0.0176]	PSNR 41.13
# Epoch: [37][380/681]	Lr 0.000200	[inte 0.00023 + grad 0.0161 + msssim 0.0008 + L2 0.0152]	PSNR 42.37
# Epoch: [37][400/681]	Lr 0.000200	[inte 0.00026 + grad 0.0172 + msssim 0.0006 + L2 0.0163]	PSNR 41.80
# Epoch: [37][420/681]	Lr 0.000200	[inte 0.00017 + grad 0.0155 + msssim 0.0006 + L2 0.0131]	PSNR 43.69
# Epoch: [37][440/681]	Lr 0.000200	[inte 0.00019 + grad 0.0153 + msssim 0.0008 + L2 0.0139]	PSNR 43.17
# Epoch: [37][460/681]	Lr 0.000200	[inte 0.00029 + grad 0.0170 + msssim 0.0006 + L2 0.0171]	PSNR 41.34
# Epoch: [37][480/681]	Lr 0.000200	[inte 0.00022 + grad 0.0169 + msssim 0.0009 + L2 0.0147]	PSNR 42.65
# Epoch: [37][500/681]	Lr 0.000200	[inte 0.00033 + grad 0.0177 + msssim 0.0019 + L2 0.0182]	PSNR 40.81
# Epoch: [37][520/681]	Lr 0.000200	[inte 0.00022 + grad 0.0164 + msssim 0.0009 + L2 0.0150]	PSNR 42.50
# Epoch: [37][540/681]	Lr 0.000200	[inte 0.00018 + grad 0.0155 + msssim 0.0006 + L2 0.0135]	PSNR 43.39
# Epoch: [37][560/681]	Lr 0.000200	[inte 0.00034 + grad 0.0170 + msssim 0.0006 + L2 0.0184]	PSNR 40.73
# Epoch: [37][580/681]	Lr 0.000200	[inte 0.00023 + grad 0.0159 + msssim 0.0005 + L2 0.0152]	PSNR 42.41
# Epoch: [37][600/681]	Lr 0.000200	[inte 0.00028 + grad 0.0157 + msssim 0.0005 + L2 0.0167]	PSNR 41.56
# Epoch: [37][620/681]	Lr 0.000200	[inte 0.00024 + grad 0.0163 + msssim 0.0016 + L2 0.0155]	PSNR 42.24
# Epoch: [37][640/681]	Lr 0.000200	[inte 0.00043 + grad 0.0206 + msssim 0.0007 + L2 0.0208]	PSNR 39.66
# Epoch: [37][660/681]	Lr 0.000200	[inte 0.00037 + grad 0.0175 + msssim 0.0006 + L2 0.0191]	PSNR 40.38
# Epoch: [37][680/681]	Lr 0.000200	[inte 0.00046 + grad 0.0201 + msssim 0.0009 + L2 0.0214]	PSNR 39.41
# => saving model state epoch_37.pth to output/ped2_synth_3/ped2_synth_3_wresnet
#
# Epoch: [38][20/681]	Lr 0.000200	[inte 0.00020 + grad 0.0153 + msssim 0.0005 + L2 0.0142]	PSNR 42.95
# Epoch: [38][40/681]	Lr 0.000200	[inte 0.00027 + grad 0.0159 + msssim 0.0015 + L2 0.0164]	PSNR 41.73
# Epoch: [38][60/681]	Lr 0.000200	[inte 0.00030 + grad 0.0183 + msssim 0.0007 + L2 0.0173]	PSNR 41.27
# Epoch: [38][80/681]	Lr 0.000200	[inte 0.00025 + grad 0.0165 + msssim 0.0020 + L2 0.0159]	PSNR 41.99
# Epoch: [38][100/681]	Lr 0.000200	[inte 0.00085 + grad 0.0351 + msssim 0.0022 + L2 0.0291]	PSNR 36.73
# Epoch: [38][120/681]	Lr 0.000200	[inte 0.00020 + grad 0.0156 + msssim 0.0006 + L2 0.0143]	PSNR 42.94
# Epoch: [38][140/681]	Lr 0.000200	[inte 0.00032 + grad 0.0174 + msssim 0.0005 + L2 0.0178]	PSNR 41.03
# Epoch: [38][160/681]	Lr 0.000200	[inte 0.00033 + grad 0.0175 + msssim 0.0014 + L2 0.0181]	PSNR 40.85
# Epoch: [38][180/681]	Lr 0.000200	[inte 0.00064 + grad 0.0166 + msssim 0.0026 + L2 0.0252]	PSNR 37.99
# Epoch: [38][200/681]	Lr 0.000200	[inte 0.00026 + grad 0.0170 + msssim 0.0006 + L2 0.0160]	PSNR 41.93
# Epoch: [38][220/681]	Lr 0.000200	[inte 0.00024 + grad 0.0161 + msssim 0.0013 + L2 0.0156]	PSNR 42.15
# Epoch: [38][240/681]	Lr 0.000200	[inte 0.00028 + grad 0.0179 + msssim 0.0007 + L2 0.0168]	PSNR 41.53
# Epoch: [38][260/681]	Lr 0.000200	[inte 0.00043 + grad 0.0163 + msssim 0.0009 + L2 0.0207]	PSNR 39.68
# Epoch: [38][280/681]	Lr 0.000200	[inte 0.00113 + grad 0.0330 + msssim 0.0009 + L2 0.0337]	PSNR 35.48
# Epoch: [38][300/681]	Lr 0.000200	[inte 0.00023 + grad 0.0159 + msssim 0.0008 + L2 0.0151]	PSNR 42.44
# Epoch: [38][320/681]	Lr 0.000200	[inte 0.00016 + grad 0.0151 + msssim 0.0007 + L2 0.0128]	PSNR 43.88
# Epoch: [38][340/681]	Lr 0.000200	[inte 0.00111 + grad 0.0333 + msssim 0.0018 + L2 0.0333]	PSNR 35.58
# Epoch: [38][360/681]	Lr 0.000200	[inte 0.00026 + grad 0.0157 + msssim 0.0005 + L2 0.0161]	PSNR 41.90
# Epoch: [38][380/681]	Lr 0.000200	[inte 0.00029 + grad 0.0172 + msssim 0.0006 + L2 0.0169]	PSNR 41.47
# Epoch: [38][400/681]	Lr 0.000200	[inte 0.00037 + grad 0.0183 + msssim 0.0013 + L2 0.0192]	PSNR 40.36
# Epoch: [38][420/681]	Lr 0.000200	[inte 0.00026 + grad 0.0162 + msssim 0.0007 + L2 0.0160]	PSNR 41.93
# Epoch: [38][440/681]	Lr 0.000200	[inte 0.00083 + grad 0.0343 + msssim 0.0019 + L2 0.0289]	PSNR 36.82
# Epoch: [38][460/681]	Lr 0.000200	[inte 0.00116 + grad 0.0335 + msssim 0.0010 + L2 0.0341]	PSNR 35.38
# Epoch: [38][480/681]	Lr 0.000200	[inte 0.00019 + grad 0.0159 + msssim 0.0009 + L2 0.0138]	PSNR 43.21
# Epoch: [38][500/681]	Lr 0.000200	[inte 0.00036 + grad 0.0177 + msssim 0.0009 + L2 0.0191]	PSNR 40.41
# Epoch: [38][520/681]	Lr 0.000200	[inte 0.00024 + grad 0.0162 + msssim 0.0008 + L2 0.0155]	PSNR 42.20
# Epoch: [38][540/681]	Lr 0.000200	[inte 0.00014 + grad 0.0148 + msssim 0.0005 + L2 0.0118]	PSNR 44.56
# Epoch: [38][560/681]	Lr 0.000200	[inte 0.00025 + grad 0.0158 + msssim 0.0018 + L2 0.0157]	PSNR 42.13
# Epoch: [38][580/681]	Lr 0.000200	[inte 0.00027 + grad 0.0155 + msssim 0.0009 + L2 0.0163]	PSNR 41.75
# Epoch: [38][600/681]	Lr 0.000200	[inte 0.00019 + grad 0.0161 + msssim 0.0008 + L2 0.0139]	PSNR 43.18
# Epoch: [38][620/681]	Lr 0.000200	[inte 0.00016 + grad 0.0152 + msssim 0.0009 + L2 0.0128]	PSNR 43.91
# Epoch: [38][640/681]	Lr 0.000200	[inte 0.00026 + grad 0.0157 + msssim 0.0007 + L2 0.0160]	PSNR 41.91
# Epoch: [38][660/681]	Lr 0.000200	[inte 0.00022 + grad 0.0152 + msssim 0.0006 + L2 0.0147]	PSNR 42.66
# Epoch: [38][680/681]	Lr 0.000200	[inte 0.00029 + grad 0.0177 + msssim 0.0007 + L2 0.0169]	PSNR 41.44
# => saving model state epoch_38.pth to output/ped2_synth_3/ped2_synth_3_wresnet
#
# Epoch: [39][20/681]	Lr 0.000200	[inte 0.00092 + grad 0.0313 + msssim 0.0010 + L2 0.0303]	PSNR 36.40
# Epoch: [39][40/681]	Lr 0.000200	[inte 0.00030 + grad 0.0175 + msssim 0.0007 + L2 0.0173]	PSNR 41.28
# Epoch: [39][60/681]	Lr 0.000200	[inte 0.00027 + grad 0.0173 + msssim 0.0008 + L2 0.0165]	PSNR 41.69
# Epoch: [39][80/681]	Lr 0.000200	[inte 0.00098 + grad 0.0345 + msssim 0.0099 + L2 0.0313]	PSNR 36.12
# Epoch: [39][100/681]	Lr 0.000200	[inte 0.00092 + grad 0.0341 + msssim 0.0047 + L2 0.0303]	PSNR 36.40
# Epoch: [39][120/681]	Lr 0.000200	[inte 0.00031 + grad 0.0183 + msssim 0.0007 + L2 0.0177]	PSNR 41.06
# Epoch: [39][140/681]	Lr 0.000200	[inte 0.00021 + grad 0.0160 + msssim 0.0005 + L2 0.0144]	PSNR 42.83
# Epoch: [39][160/681]	Lr 0.000200	[inte 0.00082 + grad 0.0330 + msssim 0.0011 + L2 0.0286]	PSNR 36.88
# Epoch: [39][180/681]	Lr 0.000200	[inte 0.00024 + grad 0.0162 + msssim 0.0006 + L2 0.0156]	PSNR 42.15
# Epoch: [39][200/681]	Lr 0.000200	[inte 0.00031 + grad 0.0154 + msssim 0.0010 + L2 0.0176]	PSNR 41.11
# Epoch: [39][220/681]	Lr 0.000200	[inte 0.00041 + grad 0.0197 + msssim 0.0006 + L2 0.0203]	PSNR 39.88
# Epoch: [39][240/681]	Lr 0.000200	[inte 0.00052 + grad 0.0178 + msssim 0.0006 + L2 0.0228]	PSNR 38.88
# Epoch: [39][260/681]	Lr 0.000200	[inte 0.00032 + grad 0.0161 + msssim 0.0011 + L2 0.0179]	PSNR 40.96
# Epoch: [39][280/681]	Lr 0.000200	[inte 0.00033 + grad 0.0191 + msssim 0.0010 + L2 0.0182]	PSNR 40.82
# Epoch: [39][300/681]	Lr 0.000200	[inte 0.00038 + grad 0.0161 + msssim 0.0008 + L2 0.0196]	PSNR 40.17
# Epoch: [39][320/681]	Lr 0.000200	[inte 0.00025 + grad 0.0169 + msssim 0.0006 + L2 0.0157]	PSNR 42.08
# Epoch: [39][340/681]	Lr 0.000200	[inte 0.00031 + grad 0.0159 + msssim 0.0017 + L2 0.0175]	PSNR 41.15
# Epoch: [39][360/681]	Lr 0.000200	[inte 0.00020 + grad 0.0160 + msssim 0.0005 + L2 0.0141]	PSNR 43.05
# Epoch: [39][380/681]	Lr 0.000200	[inte 0.00096 + grad 0.0355 + msssim 0.0044 + L2 0.0311]	PSNR 36.18
# Epoch: [39][400/681]	Lr 0.000200	[inte 0.00036 + grad 0.0187 + msssim 0.0006 + L2 0.0189]	PSNR 40.51
# Epoch: [39][420/681]	Lr 0.000200	[inte 0.00024 + grad 0.0154 + msssim 0.0005 + L2 0.0154]	PSNR 42.26
# Epoch: [39][440/681]	Lr 0.000200	[inte 0.00026 + grad 0.0170 + msssim 0.0005 + L2 0.0160]	PSNR 41.93
# Epoch: [39][460/681]	Lr 0.000200	[inte 0.00033 + grad 0.0178 + msssim 0.0008 + L2 0.0180]	PSNR 40.90
# Epoch: [39][480/681]	Lr 0.000200	[inte 0.00029 + grad 0.0154 + msssim 0.0035 + L2 0.0169]	PSNR 41.46
# Epoch: [39][500/681]	Lr 0.000200	[inte 0.00047 + grad 0.0167 + msssim 0.0010 + L2 0.0216]	PSNR 39.33
# Epoch: [39][520/681]	Lr 0.000200	[inte 0.00035 + grad 0.0166 + msssim 0.0015 + L2 0.0187]	PSNR 40.58
# Epoch: [39][540/681]	Lr 0.000200	[inte 0.00053 + grad 0.0209 + msssim 0.0007 + L2 0.0231]	PSNR 38.76
# Epoch: [39][560/681]	Lr 0.000200	[inte 0.00027 + grad 0.0161 + msssim 0.0011 + L2 0.0163]	PSNR 41.78
# Epoch: [39][580/681]	Lr 0.000200	[inte 0.00019 + grad 0.0153 + msssim 0.0012 + L2 0.0139]	PSNR 43.16
# Epoch: [39][600/681]	Lr 0.000200	[inte 0.00029 + grad 0.0174 + msssim 0.0006 + L2 0.0170]	PSNR 41.44
# Epoch: [39][620/681]	Lr 0.000200	[inte 0.00030 + grad 0.0161 + msssim 0.0015 + L2 0.0172]	PSNR 41.32
# Epoch: [39][640/681]	Lr 0.000200	[inte 0.00051 + grad 0.0191 + msssim 0.0032 + L2 0.0227]	PSNR 38.91
# Epoch: [39][660/681]	Lr 0.000200	[inte 0.00021 + grad 0.0160 + msssim 0.0007 + L2 0.0144]	PSNR 42.86
# Epoch: [39][680/681]	Lr 0.000200	[inte 0.00030 + grad 0.0158 + msssim 0.0009 + L2 0.0172]	PSNR 41.29
# => saving model state epoch_39.pth to output/ped2_synth_3/ped2_synth_3_wresnet
#
# Epoch: [40][20/681]	Lr 0.000200	[inte 0.00075 + grad 0.0300 + msssim 0.0012 + L2 0.0274]	PSNR 37.28
# Epoch: [40][40/681]	Lr 0.000200	[inte 0.00030 + grad 0.0179 + msssim 0.0006 + L2 0.0174]	PSNR 41.23
# Epoch: [40][60/681]	Lr 0.000200	[inte 0.00026 + grad 0.0154 + msssim 0.0008 + L2 0.0160]	PSNR 41.95
# Epoch: [40][80/681]	Lr 0.000200	[inte 0.00029 + grad 0.0169 + msssim 0.0012 + L2 0.0169]	PSNR 41.47
# Epoch: [40][100/681]	Lr 0.000200	[inte 0.00023 + grad 0.0167 + msssim 0.0010 + L2 0.0151]	PSNR 42.43
# Epoch: [40][120/681]	Lr 0.000200	[inte 0.00015 + grad 0.0148 + msssim 0.0005 + L2 0.0123]	PSNR 44.24
# Epoch: [40][140/681]	Lr 0.000200	[inte 0.00037 + grad 0.0180 + msssim 0.0007 + L2 0.0192]	PSNR 40.35
# Epoch: [40][160/681]	Lr 0.000200	[inte 0.00038 + grad 0.0150 + msssim 0.0005 + L2 0.0196]	PSNR 40.19
# Epoch: [40][180/681]	Lr 0.000200	[inte 0.00049 + grad 0.0164 + msssim 0.0009 + L2 0.0222]	PSNR 39.10
# Epoch: [40][200/681]	Lr 0.000200	[inte 0.00131 + grad 0.0339 + msssim 0.0015 + L2 0.0362]	PSNR 34.84
# Epoch: [40][220/681]	Lr 0.000200	[inte 0.00043 + grad 0.0215 + msssim 0.0015 + L2 0.0207]	PSNR 39.68
# Epoch: [40][240/681]	Lr 0.000200	[inte 0.00025 + grad 0.0168 + msssim 0.0008 + L2 0.0158]	PSNR 42.03
# Epoch: [40][260/681]	Lr 0.000200	[inte 0.00121 + grad 0.0359 + msssim 0.0067 + L2 0.0348]	PSNR 35.19
# Epoch: [40][280/681]	Lr 0.000200	[inte 0.00016 + grad 0.0148 + msssim 0.0009 + L2 0.0127]	PSNR 43.91
# Epoch: [40][300/681]	Lr 0.000200	[inte 0.00039 + grad 0.0191 + msssim 0.0008 + L2 0.0197]	PSNR 40.14
# Epoch: [40][320/681]	Lr 0.000200	[inte 0.00022 + grad 0.0162 + msssim 0.0007 + L2 0.0148]	PSNR 42.63
# Epoch: [40][340/681]	Lr 0.000200	[inte 0.00033 + grad 0.0159 + msssim 0.0015 + L2 0.0183]	PSNR 40.78
# Epoch: [40][360/681]	Lr 0.000200	[inte 0.00024 + grad 0.0166 + msssim 0.0007 + L2 0.0155]	PSNR 42.19
# Epoch: [40][380/681]	Lr 0.000200	[inte 0.00025 + grad 0.0154 + msssim 0.0006 + L2 0.0157]	PSNR 42.10
# Epoch: [40][400/681]	Lr 0.000200	[inte 0.00023 + grad 0.0159 + msssim 0.0007 + L2 0.0153]	PSNR 42.31
# Epoch: [40][420/681]	Lr 0.000200	[inte 0.00018 + grad 0.0150 + msssim 0.0005 + L2 0.0133]	PSNR 43.55
# Epoch: [40][440/681]	Lr 0.000200	[inte 0.00022 + grad 0.0153 + msssim 0.0018 + L2 0.0148]	PSNR 42.60
# Epoch: [40][460/681]	Lr 0.000200	[inte 0.00108 + grad 0.0326 + msssim 0.0012 + L2 0.0328]	PSNR 35.70
# Epoch: [40][480/681]	Lr 0.000200	[inte 0.00020 + grad 0.0153 + msssim 0.0006 + L2 0.0143]	PSNR 42.94
# Epoch: [40][500/681]	Lr 0.000200	[inte 0.00023 + grad 0.0153 + msssim 0.0009 + L2 0.0151]	PSNR 42.43
# Epoch: [40][520/681]	Lr 0.000200	[inte 0.00017 + grad 0.0153 + msssim 0.0005 + L2 0.0132]	PSNR 43.64
# Epoch: [40][540/681]	Lr 0.000200	[inte 0.00020 + grad 0.0156 + msssim 0.0005 + L2 0.0141]	PSNR 43.07
# Epoch: [40][560/681]	Lr 0.000200	[inte 0.00118 + grad 0.0332 + msssim 0.0012 + L2 0.0343]	PSNR 35.30
# Epoch: [40][580/681]	Lr 0.000200	[inte 0.00020 + grad 0.0146 + msssim 0.0006 + L2 0.0141]	PSNR 43.03
# Epoch: [40][600/681]	Lr 0.000200	[inte 0.00086 + grad 0.0332 + msssim 0.0047 + L2 0.0293]	PSNR 36.69
# Epoch: [40][620/681]	Lr 0.000200	[inte 0.00034 + grad 0.0187 + msssim 0.0007 + L2 0.0185]	PSNR 40.68
# Epoch: [40][640/681]	Lr 0.000200	[inte 0.00025 + grad 0.0164 + msssim 0.0011 + L2 0.0158]	PSNR 42.03
# Epoch: [40][660/681]	Lr 0.000200	[inte 0.00024 + grad 0.0151 + msssim 0.0008 + L2 0.0156]	PSNR 42.13
# Epoch: [40][680/681]	Lr 0.000200	[inte 0.00068 + grad 0.0319 + msssim 0.0025 + L2 0.0261]	PSNR 37.67
# => saving model state epoch_40.pth to output/ped2_synth_3/ped2_synth_3_wresnet
#
# saving final model state to output/ped2_synth_3/ped2_synth_3_wresnet/final_state.pth

# %% [markdown]
# Copia un epoca specifica su drive

# %%
# !cp '/content/astnet/ASTNet/output/ped2_synth_3/ped2_synth_3_wresnet/epoch_40.pth' '/content/drive/MyDrive/datasets/Training_Backup/training_ped2_synth_3_random'

# %% [markdown]
# ###Recap del training e copia del file .pth in locale per il testing

# %% [markdown]
# Epoca 40 con learning rate di 0.0002

# %%
log_files = [
    "/content/drive/MyDrive/datasets/Training_Backup/training_ped2_synth_3_random/ped2_synth_3_wresnet_2026-03-09-16-05_train.log"
]

def plot_training_results(files):
    data = []
    # Pattern per catturare Epoca, le 4 componenti della Loss e il PSNR
    pattern = re.compile(r"Epoch: \[(\d+)\]\[\d+/\d+\].*?inte ([\d\.]+) \+ grad ([\d\.]+) \+ msssim ([\d\.]+) \+ L2 ([\d\.]+)\].*?PSNR ([\d\.]+)")

    for f_path in files:
        with open(f_path, 'r') as f:
            for line in f:
                match = pattern.search(line)
                if match:
                    epoch = int(match.group(1))
                    # Loss Totale = somma delle 4 componenti
                    total_loss = float(match.group(2)) + float(match.group(3)) + \
                                 float(match.group(4)) + float(match.group(5))
                    psnr = float(match.group(6))
                    data.append({'Epoch': epoch, 'Loss': total_loss, 'PSNR': psnr})

    if not data:
        print("Nessun dato trovato. Controlla i percorsi dei file.")
        return

    # Tabella e calcolo media per epoca
    df = pd.DataFrame(data).groupby('Epoch').mean().reset_index()

    # Grafico
    fig, ax1 = plt.subplots(figsize=(12, 6))

    # Blu: PSNR (asse sinistro)
    ax1.set_xlabel('Epoca', fontsize=12)
    ax1.set_ylabel('PSNR (dB)', color='tab:blue', fontsize=12, fontweight='bold')
    ax1.plot(df['Epoch'], df['PSNR'], color='tab:blue', label='PSNR (Qualità)', linewidth=2.5)
    ax1.tick_params(axis='y', labelcolor='tab:blue')
    ax1.grid(True, linestyle='--', alpha=0.5)

    # Rosso: Total Loss (asse destro)
    ax2 = ax1.twinx()
    ax2.set_ylabel('Total Loss', color='tab:red', fontsize=12, fontweight='bold')
    ax2.plot(df['Epoch'], df['Loss'], color='tab:red', label='Loss (Errore)', linewidth=2.5)
    ax2.tick_params(axis='y', labelcolor='tab:red')
    plt.title('Analisi Training ASTNet: Evoluzione Precisione vs Errore', fontsize=14)
    fig.tight_layout()
    plt.show()


plot_training_results(log_files)

# %% [markdown]
# ###Copia in locale del modello trainato

# %%
# !cp /content/drive/MyDrive/datasets/Training_Backup/training_ped2_synth_3/epoch_40.pth /content/astnet/ASTNet/epoch_40.pth

print("File copiato con successo!")
# Out:
# File copiato con successo!

# %% [markdown]
# #4-📝Testing

# %% [markdown]
# Operazioni preliminari per evitare errori di tipo

# %%
# %cd /content/astnet/ASTNet
# !perl -pi -e 's/\bnp\.float\b/float/g; s/\bnp\.int\b/int/g; s/\bnp\.bool\b/bool/g; s/\bnp\.object\b/object/g' utils/anomaly_util.py
# Out:
# /content/astnet/ASTNet

# %%
# !pip install yacs
# Out:
# Collecting yacs
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from yacs) (6.0.3)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Installing collected packages: yacs
# Successfully installed yacs-0.1.8

# %% [markdown]
# UTILIZZIAMO FRAME_STEPS=2

# %% [markdown]
# ##4.1-Test ped2

# %%
# %cd /content/astnet/ASTNet
# !python test.py \
  --cfg config/ped2_wresnet.yaml \
  --model-file output/ped2_synth_3/ped2_synth_3_wresnet/epoch_40.pth
# Out:
# /content/astnet/ASTNet
# => creating output/ped2/ped2_wresnet
# => creating log/ped2/wrn38/ped2_wresnet_2026-03-10-11-18
# Namespace(cfg='config/ped2_wresnet.yaml', model_file='output/ped2_synth_3/ped2_synth_3_wresnet/epoch_40.pth', opts=[])
# CfgNode({'OUTPUT_DIR': 'output', 'LOG_DIR': 'log', 'GPUS': (0,), 'WORKERS': 2, 'PRINT_FREQ': 20, 'SAVE_CHECKPOINT_FREQ': 1, 'AUTO_RESUME': False, 'PIN_MEMORY': True, 'CUDNN': CfgNode({'BENCHMARK': True, 'DETERMINISTIC': False, 'ENABLED': True}), 'DATASET': CfgNode({'ROOT': '/content/drive/MyDrive/datasets', 'DATASET': 'ped2', 'TRAINSET': 'training/frames', 'TESTSET': 'testing/frames', 'NUM_INCHANNELS': 3, 'NUM_FRAMES': 5, 'FRAME_STEPS': 2, 'LOWER_BOUND': 100}), 'TRAIN': CfgNode({'BATCH_SIZE_PER_GPU': 2, 'SHUFFLE': True, 'BEGIN_EPOCH': 0, 'END_EPOCH': 40, 'RESUME': False, 'CHECKPOINT': '', 'OPTIMIZER': 'adam', 'MOMENTUM': 0.0, 'WD': 0.0, 'NESTEROV': False, 'LR_TYPE': 'multistep', 'LR': 0.0002, 'LR_STEP': [50, 65], 'LR_FACTOR': 0.5}), 'TEST': CfgNode({'BATCH_SIZE_PER_GPU': 1}), 'MODEL': CfgNode({'NAME': 'wrn38', 'INIT_WEIGHTS': True, 'PRETRAINED': '/content/astnet/ASTNet/datasets/seg_weights/wider_resnet38.pth', 'IMAGE_SIZE': [224, 288], 'MEMORY_SIZE': 5, 'ENCODED_FRAMES': 4, 'DECODED_FRAMES': 0, 'EXTRA': CfgNode({'FINAL_CONV_KERNEL': 3})})})
# => wrn38_1024: (CATTN + TSM) - Ped2
# Global Average Pooling Initialized
# => Using fold div: 16
# Model: wrn38
# Epoch:
# [1/12]
# 100% 176/176 [00:56<00:00,  3.10it/s]
# [2/12]
# 100% 176/176 [00:53<00:00,  3.31it/s]
# [3/12]
# 100% 146/146 [00:46<00:00,  3.15it/s]
# [4/12]
# 100% 176/176 [00:55<00:00,  3.16it/s]
# [5/12]
# 100% 146/146 [00:46<00:00,  3.16it/s]
# [6/12]
# 100% 176/176 [00:55<00:00,  3.15it/s]
# [7/12]
# 100% 176/176 [00:55<00:00,  3.16it/s]
# [8/12]
# 100% 176/176 [00:55<00:00,  3.17it/s]
# [9/12]
# 100% 116/116 [00:36<00:00,  3.16it/s]
# [10/12]
# 100% 146/146 [00:46<00:00,  3.17it/s]
# [11/12]
# 100% 176/176 [00:55<00:00,  3.15it/s]
# [12/12]
# 100% 176/176 [00:55<00:00,  3.17it/s]
# Saved psnr_list.npy, gt_list.npy, roc_fpr.npy, roc_tpr.npy in output/ped2/ped2_wresnet
# AUC: 96.8%

# %% [markdown]
# Salvataggio del test su drive

# %%
# !cp -r /content/astnet/ASTNet/output/ped2 /content/drive/MyDrive/datasets/ASTNet_results/train_with_ped2_synth_3_random

# %% [markdown]
# ##4.3-Test MED

# %%
# %cd /content/astnet/ASTNet
# !python test.py \
  --cfg config/med_wresnet.yaml \
  --model-file output/ped2_synth_3/ped2_synth_3_wresnet/epoch_40.pth
# Out:
# /content/astnet/ASTNet
# => creating output/med/med_wresnet
# => creating log/med/wrn38/med_wresnet_2026-03-10-07-15
# Namespace(cfg='config/med_wresnet.yaml', model_file='output/ped2_synth_3/ped2_synth_3_wresnet/epoch_40.pth', opts=[])
# CfgNode({'OUTPUT_DIR': 'output', 'LOG_DIR': 'log', 'GPUS': (0,), 'WORKERS': 0, 'PRINT_FREQ': 1, 'SAVE_CHECKPOINT_FREQ': 1, 'AUTO_RESUME': False, 'PIN_MEMORY': True, 'CUDNN': CfgNode({'BENCHMARK': True, 'DETERMINISTIC': False, 'ENABLED': True}), 'DATASET': CfgNode({'ROOT': '/content/astnet/data/', 'DATASET': 'med', 'TRAINSET': 'training/frames', 'TESTSET': 'testing/frames', 'NUM_INCHANNELS': 3, 'NUM_FRAMES': 5, 'FRAME_STEPS': 2, 'LOWER_BOUND': 0}), 'TRAIN': CfgNode({'BATCH_SIZE_PER_GPU': 2, 'SHUFFLE': True, 'BEGIN_EPOCH': 0, 'END_EPOCH': 120, 'RESUME': True, 'CHECKPOINT': '', 'OPTIMIZER': 'adam', 'MOMENTUM': 0.0, 'WD': 0.0, 'NESTEROV': False, 'LR_TYPE': 'multistep', 'LR': 0.0002, 'LR_STEP': [80, 100], 'LR_FACTOR': 0.5}), 'TEST': CfgNode({'BATCH_SIZE_PER_GPU': 1}), 'MODEL': CfgNode({'NAME': 'wrn38', 'INIT_WEIGHTS': True, 'PRETRAINED': '../../datasets/seg_weights/wider_resnet38.pth', 'IMAGE_SIZE': [224, 288], 'MEMORY_SIZE': 5, 'ENCODED_FRAMES': 4, 'DECODED_FRAMES': 0, 'EXTRA': CfgNode({'FINAL_CONV_KERNEL': 3})})})
# => wrn38_1024: (CATTN + TSM) - Ped2
# Global Average Pooling Initialized
# => Using fold div: 16
# Model: wrn38
# Epoch:
# [1/31]
# 100% 1674/1674 [08:46<00:00,  3.18it/s]
# [2/31]
# 100% 1315/1315 [06:51<00:00,  3.20it/s]
# [3/31]
# 100% 1045/1045 [05:27<00:00,  3.19it/s]
# [4/31]
# 100% 1135/1135 [05:55<00:00,  3.19it/s]
# [5/31]
# 100% 1165/1165 [06:04<00:00,  3.19it/s]
# [6/31]
# 100% 1105/1105 [05:45<00:00,  3.19it/s]
# [7/31]
# 100% 1225/1225 [06:23<00:00,  3.20it/s]
# [8/31]
# 100% 955/955 [05:00<00:00,  3.18it/s]
# [9/31]
# 100% 1105/1105 [05:46<00:00,  3.19it/s]
# [10/31]
# 100% 2634/2634 [13:46<00:00,  3.19it/s]
# [11/31]
# 100% 2454/2454 [12:50<00:00,  3.19it/s]
# [12/31]
# 100% 925/925 [04:51<00:00,  3.18it/s]
# [13/31]
# 100% 626/626 [03:16<00:00,  3.18it/s]
# [14/31]
# 100% 805/805 [04:13<00:00,  3.18it/s]
# [15/31]
# 100% 1345/1345 [07:02<00:00,  3.18it/s]
# [16/31]
# 100% 1644/1644 [08:36<00:00,  3.19it/s]
# [17/31]
# 100% 1585/1585 [08:17<00:00,  3.18it/s]
# [18/31]
# 100% 895/895 [04:41<00:00,  3.18it/s]
# [19/31]
# 100% 1674/1674 [08:44<00:00,  3.19it/s]
# [20/31]
# 100% 1824/1824 [09:32<00:00,  3.19it/s]
# [21/31]
# 100% 1495/1495 [07:47<00:00,  3.19it/s]
# [22/31]
# 100% 1555/1555 [08:07<00:00,  3.19it/s]
# [23/31]
# 100% 1435/1435 [07:30<00:00,  3.19it/s]
# [24/31]
# 100% 1255/1255 [06:33<00:00,  3.19it/s]
# [25/31]
# 100% 1255/1255 [06:34<00:00,  3.18it/s]
# [26/31]
# 100% 1614/1614 [08:27<00:00,  3.18it/s]
# [27/31]
# 100% 1704/1704 [08:55<00:00,  3.18it/s]
# [28/31]
# 100% 1045/1045 [05:28<00:00,  3.18it/s]
# [29/31]
# 100% 1345/1345 [07:02<00:00,  3.19it/s]
# [30/31]
# 100% 2934/2934 [15:20<00:00,  3.19it/s]
# [31/31]
# 100% 1195/1195 [06:15<00:00,  3.18it/s]
# Saved psnr_list.npy, gt_list.npy, roc_fpr.npy, roc_tpr.npy in output/med/med_wresnet
# AUC: 66.4%

# %%
# !cp -r /content/astnet/ASTNet/output/med /content/drive/MyDrive/datasets/ASTNet_results/train_with_ped2_synth_3_random/

# %% [markdown]
# #5-📈Results

# %% [markdown]
# ##5.1 Ped2

# %% [markdown]
# ###Plot

# %%
OUT_DIR = Path("/content/drive/MyDrive/datasets/ASTNet_results/train_with_ped2_synth_3_random/ped2/ped2_wresnet")
FRAMES_DIR = Path("/content/drive/MyDrive/datasets/ped2/testing/frames")

# Caricamento dei dati dai file .npy generati dal test
try:
    psnr_list = np.load(OUT_DIR / "psnr_list.npy", allow_pickle=True)
    gt_list   = np.load(OUT_DIR / "gt_list.npy", allow_pickle=True)
except FileNotFoundError:
    psnr_list = np.load(OUT_DIR / "psnr.npy", allow_pickle=True)
    gt_list   = np.load(OUT_DIR / "gt.npy", allow_pickle=True)

# Recupero nomi delle cartelle video
video_names = sorted([p.name for p in FRAMES_DIR.iterdir() if p.is_dir()])

fp = 4  # encoded_frames + decoded_frames


# Score continuo
def anomaly_score_from_psnr(psnr_video):
    psnr_video = np.asarray(psnr_video, dtype=float)
    # Normalizzazione Min-Max invertita (PSNR basso = Score alto)
    psnr_norm = (psnr_video - psnr_video.min()) / (psnr_video.max() - psnr_video.min() + 1e-12)
    return 1.0 - psnr_norm

def align_gt_to_psnr(gt_video, psnr_video, fp=4):
    gt = np.asarray(gt_video).astype(int).ravel()
    Lp = len(psnr_video)
    if len(gt) == Lp + fp:
        return gt[fp:fp+Lp]
    if len(gt) == Lp:
        return gt
    return gt[:Lp]

#-------
# Calcolo soglia globale dal ROC (Youden J)
#-------
all_scores = []
all_gts = []

for psnr_video, gt_video in zip(psnr_list, gt_list):
    score = anomaly_score_from_psnr(psnr_video)
    gt_aligned = align_gt_to_psnr(gt_video, psnr_video, fp)
    L = min(len(score), len(gt_aligned))
    all_scores.append(score[:L])
    all_gts.append(gt_aligned[:L])

all_scores = np.concatenate(all_scores)
all_gts = np.concatenate(all_gts)

fpr, tpr, thr = roc_curve(all_gts, all_scores)
best_thr = thr[np.argmax(tpr - fpr)]
print(f"Soglia globale ottimale (Youden) per Ped2: {best_thr:.4f}")

#-------
# Plot
#-------
def plot_video_ped2(idx, thr=best_thr):
    psnr_video = psnr_list[idx]
    score = anomaly_score_from_psnr(psnr_video)

    gt_aligned = align_gt_to_psnr(gt_list[idx], psnr_video, fp)
    pred = (score >= thr).astype(int)

    L = min(len(score), len(gt_aligned), len(pred))
    score = score[:L]
    gt_aligned = gt_aligned[:L]
    pred = pred[:L]

    # Gestione nome video
    name = video_names[idx] if idx < len(video_names) else f"Video {idx+1}"

    colors = np.empty(L, dtype=object)
    colors[:] = 'none'

    # Blu: Anomalia reale non vista (False Negative)
    colors[(gt_aligned == 1) & (pred == 0)] = '#0066FF'
    # Rosso: Allarme dove non c'è anomalia (False Positive)
    colors[(pred == 1) & (gt_aligned == 0)] = '#8B0000'
    # Verde: Anomalia rilevata correttamente (True Positive)
    colors[(gt_aligned == 1) & (pred == 1)] = '#00C853'

    fig, ax = plt.subplots(figsize=(12, 2.5))

    ax.plot(score, color="black", linewidth=1.2, label="Anomaly score", zorder=3)
    ax.axhline(y=thr, color='red', linestyle='--', linewidth=1, label='Soglia', zorder=2)

    for i in range(L):
        if colors[i] != 'none':
            ax.axvspan(i-0.5, i+0.5, ymin=0, ymax=1,
                       color=colors[i], alpha=0.4, zorder=1)

    legend_elements = [
        plt.Line2D([0], [0], color='black', linewidth=1.2, label='Anomaly score'),
        plt.Line2D([0], [0], color='red', linestyle='--', label='Soglia'),
        Patch(facecolor='#0066FF', alpha=0.4, label='Solo Ground Truth'),
        Patch(facecolor='#8B0000', alpha=0.4, label='Solo Predizione (FP)'),
        Patch(facecolor='#00C853', alpha=0.4, label='Rilevamento Corretto')
    ]

    ax.set_title(f"UCSD Ped2 – {name}")
    ax.set_xlabel("Frame")
    ax.set_ylabel("Score")
    ax.set_ylim(0, 1.05)
    ax.set_xlim(-0.5, L-0.5)
    ax.legend(handles=legend_elements, loc="center left", bbox_to_anchor=(1, 0.5))

    plt.tight_layout()
    plt.show()

# Esecuzione finale
num_videos = len(psnr_list)
print(f"Numero totale di video trovati: {num_videos}")

for i in range(num_videos):
    plot_video_ped2(i)
# Out:
# Soglia globale ottimale (Youden) per Ped2: 0.2150
# Numero totale di video trovati: 12

# %% [markdown]
# ###ROC CURVE

# %%
OUT_DIR = Path("/content/drive/MyDrive/datasets/ASTNet_results/train_with_ped2_synth_3_random/ped2/ped2_wresnet")

psnr_list = np.load(OUT_DIR / "psnr_list.npy", allow_pickle=True)
gt_list   = np.load(OUT_DIR / "gt_list.npy", allow_pickle=True)

print("N video psnr:", len(psnr_list))
print("N video gt:", len(gt_list))

fp = 4  # ENCODED_FRAMES + DECODED_FRAMES

def anomaly_score_from_psnr(psnr_video):
    psnr_video = np.asarray(psnr_video, dtype=float)
    psnr_norm = (psnr_video - psnr_video.min()) / (psnr_video.max() - psnr_video.min() + 1e-12)
    return 1.0 - psnr_norm

def align_gt_to_psnr(gt_video, psnr_video, fp=4):
    gt = np.asarray(gt_video).astype(int).ravel()
    Lp = len(psnr_video)
    if len(gt) == Lp + fp:
        return gt[fp:fp+Lp]
    if len(gt) == Lp:
        return gt
    return gt[:Lp]

# Calcola scores
all_scores = []
all_gts = []

for psnr_video, gt_video in zip(psnr_list, gt_list):
    score = anomaly_score_from_psnr(psnr_video)
    gt_aligned = align_gt_to_psnr(gt_video, psnr_video, fp)

    L = min(len(score), len(gt_aligned))
    all_scores.append(score[:L])
    all_gts.append(gt_aligned[:L])

all_scores = np.concatenate(all_scores)
all_gts = np.concatenate(all_gts)

# Calcola AUC
auc = roc_auc_score(all_gts, all_scores)
print(f"AUC complessiva (PED2): {auc * 100:.1f}%")

# ROC
fpr, tpr, _ = roc_curve(all_gts, all_scores)

plt.figure(figsize=(5, 5))
plt.plot(fpr, tpr, label=f"AUC = {auc*100:.1f}%", linewidth=2)
plt.plot([0, 1], [0, 1], "k--", alpha=0.3, label="Random")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve – PED2 Dataset")
plt.legend(loc="lower right")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# N video psnr: 12
# N video gt: 12
# AUC complessiva (PED2): 96.8%

# %% [markdown]
# ###Confusion matrix

# %%
OUT_DIR = Path("/content/drive/MyDrive/datasets/ASTNet_results/train_with_ped2_synth_3_random/ped2/ped2_wresnet")

psnr_list = np.load(OUT_DIR / "psnr_list.npy", allow_pickle=True)
gt_list   = np.load(OUT_DIR / "gt_list.npy", allow_pickle=True)

fp = 4  # ENCODED_FRAMES + DECODED_FRAMES

# Definisci le funzioni
def anomaly_score_from_psnr(psnr_video):
    psnr_video = np.asarray(psnr_video, dtype=float)
    psnr_norm = (psnr_video - psnr_video.min()) / (psnr_video.max() - psnr_video.min() + 1e-12)
    return 1.0 - psnr_norm

def align_gt_to_psnr(gt_video, psnr_video, fp=4):
    gt = np.asarray(gt_video).astype(int).ravel()
    Lp = len(psnr_video)
    if len(gt) == Lp + fp:
        return gt[fp:fp+Lp]
    if len(gt) == Lp:
        return gt
    return gt[:Lp]

# Calcolo degli scores e GT
all_scores = []
all_gts = []

for psnr_video, gt_video in zip(psnr_list, gt_list):
    score = anomaly_score_from_psnr(psnr_video)
    gt_aligned = align_gt_to_psnr(gt_video, psnr_video, fp)

    L = min(len(score), len(gt_aligned))
    all_scores.append(score[:L])
    all_gts.append(gt_aligned[:L])

all_scores = np.concatenate(all_scores)
all_gts = np.concatenate(all_gts)

# Calcola soglia ottimale (Youden index)
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(all_gts, all_scores)
best_threshold = thresholds[np.argmax(tpr - fpr)]
print(f"Soglia ottimale (Youden): {best_threshold:.4f}")

# Predizioni binarie
y_pred = (all_scores >= best_threshold).astype(int)

# Calcola metriche
accuracy = accuracy_score(all_gts, y_pred)
precision = precision_score(all_gts, y_pred)
recall = recall_score(all_gts, y_pred)
f1 = f1_score(all_gts, y_pred)

print("\n=== METRICHE PED2 ===")
print(f"Accuracy:  {accuracy * 100:.2f}%")
print(f"Precision: {precision * 100:.2f}%")
print(f"Recall:    {recall * 100:.2f}%")
print(f"F1-Score:  {f1 * 100:.2f}%")

# Matrice di confusione
cm = confusion_matrix(all_gts, y_pred)
print("\nMatrice di Confusione:")
print(cm)

# Plot matrice di confusione
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Normal', 'Anomaly'],
            yticklabels=['Normal', 'Anomaly'],
            cbar_kws={'label': 'Count'})
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix – Ped2 Dataset')
plt.tight_layout()
plt.show()

# Stampa dettagli matrice
tn, fp, fn, tp = cm.ravel()
print("\nDettagli:")
print(f"True Negatives:  {tn}")
print(f"False Positives: {fp}")
print(f"False Negatives: {fn}")
print(f"True Positives:  {tp}")
# Out:
# Soglia ottimale (Youden): 0.2150
#
# === METRICHE PED2 ===
# Accuracy:  89.50%
# Precision: 99.10%
# Recall:    88.09%
# F1-Score:  93.27%
#
# Matrice di Confusione:
# [[ 329   13]
#  [ 193 1427]]
# Dettagli:
# True Negatives:  329
# False Positives: 13
# False Negatives: 193
# True Positives:  1427

# %% [markdown]
# ##5.2 MED

# %% [markdown]
# ###Plot

# %%
OUT_DIR = Path("/content/drive/MyDrive/datasets/ASTNet_results/train_with_ped2_synth_3_random/med/med_wresnet")
FRAMES_DIR = Path("/content/drive/MyDrive/datasets/med/testing/frames")

# Caricamento dei dati dai file .npy generati dal test
try:
    psnr_list = np.load(OUT_DIR / "psnr_list.npy", allow_pickle=True)
    gt_list   = np.load(OUT_DIR / "gt_list.npy", allow_pickle=True)
except FileNotFoundError:
    psnr_list = np.load(OUT_DIR / "psnr.npy", allow_pickle=True)
    gt_list   = np.load(OUT_DIR / "gt.npy", allow_pickle=True)

# Recupero nomi delle cartelle video
video_names = sorted([p.name for p in FRAMES_DIR.iterdir() if p.is_dir()])

fp = 4  # encoded_frames + decoded_frames


# Score continuo
def anomaly_score_from_psnr(psnr_video):
    psnr_video = np.asarray(psnr_video, dtype=float)
    # Normalizzazione Min-Max invertita (PSNR basso = Score alto)
    psnr_norm = (psnr_video - psnr_video.min()) / (psnr_video.max() - psnr_video.min() + 1e-12)
    return 1.0 - psnr_norm

def align_gt_to_psnr(gt_video, psnr_video, fp=4):
    gt = np.asarray(gt_video).astype(int).ravel()
    Lp = len(psnr_video)
    if len(gt) == Lp + fp:
        return gt[fp:fp+Lp]
    if len(gt) == Lp:
        return gt
    return gt[:Lp]

#-------
# Calcolo soglia globale dal ROC (Youden J)
#-------
all_scores = []
all_gts = []

for psnr_video, gt_video in zip(psnr_list, gt_list):
    score = anomaly_score_from_psnr(psnr_video)
    gt_aligned = align_gt_to_psnr(gt_video, psnr_video, fp)
    L = min(len(score), len(gt_aligned))
    all_scores.append(score[:L])
    all_gts.append(gt_aligned[:L])

all_scores = np.concatenate(all_scores)
all_gts = np.concatenate(all_gts)

fpr, tpr, thr = roc_curve(all_gts, all_scores)
best_thr = thr[np.argmax(tpr - fpr)]
print(f"Soglia globale ottimale (Youden) per MED: {best_thr:.4f}")

#-------
# Plot
#-------
def plot_video_ped2(idx, thr=best_thr):
    psnr_video = psnr_list[idx]
    score = anomaly_score_from_psnr(psnr_video)

    gt_aligned = align_gt_to_psnr(gt_list[idx], psnr_video, fp)
    pred = (score >= thr).astype(int)

    L = min(len(score), len(gt_aligned), len(pred))
    score = score[:L]
    gt_aligned = gt_aligned[:L]
    pred = pred[:L]

    # Gestione nome video
    name = video_names[idx] if idx < len(video_names) else f"Video {idx+1}"

    colors = np.empty(L, dtype=object)
    colors[:] = 'none'

    # Blu: Anomalia reale non vista (False Negative)
    colors[(gt_aligned == 1) & (pred == 0)] = '#0066FF'
    # Rosso: Allarme dove non c'è anomalia (False Positive)
    colors[(pred == 1) & (gt_aligned == 0)] = '#8B0000'
    # Verde: Anomalia rilevata correttamente (True Positive)
    colors[(gt_aligned == 1) & (pred == 1)] = '#00C853'

    fig, ax = plt.subplots(figsize=(12, 2.5))

    ax.plot(score, color="black", linewidth=1.2, label="Anomaly score", zorder=3)
    ax.axhline(y=thr, color='red', linestyle='--', linewidth=1, label='Soglia', zorder=2)

    for i in range(L):
        if colors[i] != 'none':
            ax.axvspan(i-0.5, i+0.5, ymin=0, ymax=1,
                       color=colors[i], alpha=0.4, zorder=1)

    legend_elements = [
        plt.Line2D([0], [0], color='black', linewidth=1.2, label='Anomaly score'),
        plt.Line2D([0], [0], color='red', linestyle='--', label='Soglia'),
        Patch(facecolor='#0066FF', alpha=0.4, label='Solo Ground Truth'),
        Patch(facecolor='#8B0000', alpha=0.4, label='Solo Predizione (FP)'),
        Patch(facecolor='#00C853', alpha=0.4, label='Rilevamento Corretto')
    ]

    ax.set_title(f"MED – {name}")
    ax.set_xlabel("Frame")
    ax.set_ylabel("Score")
    ax.set_ylim(0, 1.05)
    ax.set_xlim(-0.5, L-0.5)
    ax.legend(handles=legend_elements, loc="center left", bbox_to_anchor=(1, 0.5))

    plt.tight_layout()
    plt.show()

# Esecuzione finale
num_videos = len(psnr_list)
print(f"Numero totale di video trovati: {num_videos}")

for i in range(num_videos):
    plot_video_ped2(i)
# Out:
# Soglia globale ottimale (Youden) per MED: 0.3477
# Numero totale di video trovati: 31

# %% [markdown]
# ###ROC CURVE

# %%
OUT_DIR = Path("/content/drive/MyDrive/datasets/ASTNet_results/train_with_ped2_synth_3_random/med/med_wresnet")

psnr_list = np.load(OUT_DIR / "psnr_list.npy", allow_pickle=True)
gt_list   = np.load(OUT_DIR / "gt_list.npy", allow_pickle=True)

print("N video psnr:", len(psnr_list))
print("N video gt:", len(gt_list))

fp = 4  # ENCODED_FRAMES + DECODED_FRAMES

def anomaly_score_from_psnr(psnr_video):
    psnr_video = np.asarray(psnr_video, dtype=float)
    psnr_norm = (psnr_video - psnr_video.min()) / (psnr_video.max() - psnr_video.min() + 1e-12)
    return 1.0 - psnr_norm

def align_gt_to_psnr(gt_video, psnr_video, fp=4):
    gt = np.asarray(gt_video).astype(int).ravel()
    Lp = len(psnr_video)
    if len(gt) == Lp + fp:
        return gt[fp:fp+Lp]
    if len(gt) == Lp:
        return gt
    return gt[:Lp]

# Calcola scores
all_scores = []
all_gts = []

for psnr_video, gt_video in zip(psnr_list, gt_list):
    score = anomaly_score_from_psnr(psnr_video)
    gt_aligned = align_gt_to_psnr(gt_video, psnr_video, fp)

    L = min(len(score), len(gt_aligned))
    all_scores.append(score[:L])
    all_gts.append(gt_aligned[:L])

all_scores = np.concatenate(all_scores)
all_gts = np.concatenate(all_gts)

# Calcola AUC
auc = roc_auc_score(all_gts, all_scores)
print(f"AUC complessiva (MED): {auc * 100:.1f}%")

# ROC
fpr, tpr, _ = roc_curve(all_gts, all_scores)

plt.figure(figsize=(5, 5))
plt.plot(fpr, tpr, label=f"AUC = {auc*100:.1f}%", linewidth=2)
plt.plot([0, 1], [0, 1], "k--", alpha=0.3, label="Random")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve – MED Dataset")
plt.legend(loc="lower right")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# N video psnr: 31
# N video gt: 31
# AUC complessiva (MED): 66.4%

# %% [markdown]
# ###Confusion matrix

# %%
OUT_DIR = Path("/content/drive/MyDrive/datasets/ASTNet_results/train_with_ped2_synth_3_random/med/med_wresnet")

psnr_list = np.load(OUT_DIR / "psnr_list.npy", allow_pickle=True)
gt_list   = np.load(OUT_DIR / "gt_list.npy", allow_pickle=True)

fp = 4  # ENCODED_FRAMES + DECODED_FRAMES

# Definisci le funzioni
def anomaly_score_from_psnr(psnr_video):
    psnr_video = np.asarray(psnr_video, dtype=float)
    psnr_norm = (psnr_video - psnr_video.min()) / (psnr_video.max() - psnr_video.min() + 1e-12)
    return 1.0 - psnr_norm

def align_gt_to_psnr(gt_video, psnr_video, fp=4):
    gt = np.asarray(gt_video).astype(int).ravel()
    Lp = len(psnr_video)
    if len(gt) == Lp + fp:
        return gt[fp:fp+Lp]
    if len(gt) == Lp:
        return gt
    return gt[:Lp]

# Calcolo degli scores e GT
all_scores = []
all_gts = []

for psnr_video, gt_video in zip(psnr_list, gt_list):
    score = anomaly_score_from_psnr(psnr_video)
    gt_aligned = align_gt_to_psnr(gt_video, psnr_video, fp)

    L = min(len(score), len(gt_aligned))
    all_scores.append(score[:L])
    all_gts.append(gt_aligned[:L])

all_scores = np.concatenate(all_scores)
all_gts = np.concatenate(all_gts)

# Calcola soglia ottimale (Youden index)
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(all_gts, all_scores)
best_threshold = thresholds[np.argmax(tpr - fpr)]
print(f"Soglia ottimale (Youden): {best_threshold:.4f}")

# Predizioni binarie
y_pred = (all_scores >= best_threshold).astype(int)

# Calcola metriche
accuracy = accuracy_score(all_gts, y_pred)
precision = precision_score(all_gts, y_pred)
recall = recall_score(all_gts, y_pred)
f1 = f1_score(all_gts, y_pred)

print("\n=== METRICHE MED ===")
print(f"Accuracy:  {accuracy * 100:.2f}%")
print(f"Precision: {precision * 100:.2f}%")
print(f"Recall:    {recall * 100:.2f}%")
print(f"F1-Score:  {f1 * 100:.2f}%")

# Matrice di confusione
cm = confusion_matrix(all_gts, y_pred)
print("\nMatrice di Confusione:")
print(cm)

# Plot matrice di confusione
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Normal', 'Anomaly'],
            yticklabels=['Normal', 'Anomaly'],
            cbar_kws={'label': 'Count'})
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix – MED Dataset')
plt.tight_layout()
plt.show()

# Stampa dettagli matrice
tn, fp, fn, tp = cm.ravel()
print("\nDettagli:")
print(f"True Negatives:  {tn}")
print(f"False Positives: {fp}")
print(f"False Negatives: {fn}")
print(f"True Positives:  {tp}")
# Out:
# Soglia ottimale (Youden): 0.3477
#
# === METRICHE MED ===
# Accuracy:  64.97%
# Precision: 56.80%
# Recall:    56.65%
# F1-Score:  56.72%
#
# Matrice di Confusione:
# [[18475  7676]
#  [ 7724 10092]]
# Dettagli:
# True Negatives:  18475
# False Positives: 7676
# False Negatives: 7724
# True Positives:  10092

# %% [markdown]
# #Curva ROC di tutti gli esperimenti effettuati

# %%
experiments = [
    {
        "name": "Ped2",
        "path": "/content/drive/MyDrive/datasets/ASTNet_results/train_with_ped2/med/med_wresnet",
        "color": "black",
        "linestyle": "-",
        "linewidth": 3
    },
    {
        "name": "Pre-train ped2",
        "path": "/content/drive/MyDrive/datasets/ASTNet_results/pretrain_with_ped2/med/med_wresnet",
        "color": "grey",
        "linestyle": "-",
        "linewidth": 3
    },
    {
        "name": "90/10 (manual selection)",
        "path": "/content/drive/MyDrive/datasets/ASTNet_results/train_with_ped2_synth_3/med/med_wresnet",
        "color": "blue",
        "linestyle": "-",
        "linewidth": 2
    },
    {
        "name": "90/10 (random selection)",
        "path": "/content/drive/MyDrive/datasets/ASTNet_results/train_with_ped2_synth_3_random/med/med_wresnet",
        "color": "#5DADE2",
        "linestyle": "--",
        "linewidth": 2
    },
    {
        "name": "75/25 (manual selection)",
        "path": "/content/drive/MyDrive/datasets/ASTNet_results/train_with_ped2_synth_2/med/med_wresnet",
        "color": "green",
        "linestyle": "-",
        "linewidth": 2
    },
    {
        "name": "75/25 (random selection)",
        "path": "/content/drive/MyDrive/datasets/ASTNet_results/train_with_ped2_synth_2_random/med/med_wresnet",
        "color": "#66c266",
        "linestyle": "--",
        "linewidth": 2
    },
    {
        "name": "50/50 (manual selection)",
        "path": "/content/drive/MyDrive/datasets/ASTNet_results/train_with_ped2_synth/med/med_wresnet",
        "color": "orange",
        "linestyle": "-",
        "linewidth": 2
    },


    {
        "name": "50/50 (random selection)",
        "path": "/content/drive/MyDrive/datasets/ASTNet_results/train_with_ped2_synth_random/med/med_wresnet",
        "color": "#ffbb78",
        "linestyle": "--",
        "linewidth": 2
    },
    {
        "name": "Only synthetic data",
        "path": "/content/drive/MyDrive/datasets/ASTNet_results/train_with_synth/med/med_wresnet",
        "color": "red",
        "linestyle": "--",
        "linewidth": 2
    }


]



fp = 4  # ENCODED_FRAMES + DECODED_FRAMES

def anomaly_score_from_psnr(psnr_video):
    psnr_video = np.asarray(psnr_video, dtype=float)
    psnr_norm = (psnr_video - psnr_video.min()) / (psnr_video.max() - psnr_video.min() + 1e-12)
    return 1.0 - psnr_norm

def align_gt_to_psnr(gt_video, psnr_video, fp=4):
    gt = np.asarray(gt_video).astype(int).ravel()
    Lp = len(psnr_video)
    if len(gt) == Lp + fp:
        return gt[fp:fp+Lp]
    if len(gt) == Lp:
        return gt
    return gt[:Lp]

def compute_auc(out_dir):
    """Calcola AUC per un esperimento"""
    out_dir = Path(out_dir)

    psnr_list = np.load(out_dir / "psnr_list.npy", allow_pickle=True)
    gt_list = np.load(out_dir / "gt_list.npy", allow_pickle=True)

    all_scores = []
    all_gts = []

    for psnr_video, gt_video in zip(psnr_list, gt_list):
        score = anomaly_score_from_psnr(psnr_video)
        gt_aligned = align_gt_to_psnr(gt_video, psnr_video, fp)

        L = min(len(score), len(gt_aligned))
        all_scores.append(score[:L])
        all_gts.append(gt_aligned[:L])

    all_scores = np.concatenate(all_scores)
    all_gts = np.concatenate(all_gts)

    auc = roc_auc_score(all_gts, all_scores)
    fpr, tpr, _ = roc_curve(all_gts, all_scores)

    return auc, fpr, tpr


# PLOT
plt.figure(figsize=(8, 6))

# Plot ogni esperimento
for exp in experiments:
    print(f"📊 Processing: {exp['name']}")
    auc, fpr, tpr = compute_auc(exp['path'])
    print(f"   AUC = {auc*100:.1f}%\n")

    plt.plot(fpr, tpr,
             label=f"{exp['name']} (AUC={auc*100:.1f}%)",
             color=exp['color'],
             linestyle=exp['linestyle'],
             linewidth=exp['linewidth'])
             #linewidth=2)

# Linea random
plt.plot([0, 1], [0, 1], "k--", alpha=0.2, label="Random", linewidth=1)

# Configurazione grafico
plt.xlabel("False Positive Rate", fontsize=12)
plt.ylabel("True Positive Rate", fontsize=12)
plt.title("ROC Curves for Cross-Dataset Evaluation on MED", fontsize=14, fontweight='bold')
plt.legend(loc="lower right", fontsize=10)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# 📊 Processing: Ped2
#    AUC = 69.1%
#
# 📊 Processing: Pre-train ped2
#    AUC = 59.4%
#
# 📊 Processing: 90/10 (manual selection)
#    AUC = 70.5%
#
# 📊 Processing: 90/10 (random selection)
#    AUC = 66.4%
#
# 📊 Processing: 75/25 (manual selection)
#    AUC = 64.8%
#
# 📊 Processing: 75/25 (random selection)
#    AUC = 57.3%
#
# 📊 Processing: 50/50 (manual selection)
#    AUC = 63.2%
#
# 📊 Processing: 50/50 (random selection)
#    AUC = 61.3%
#
# 📊 Processing: Only synthetic data
#    AUC = 56.6%
